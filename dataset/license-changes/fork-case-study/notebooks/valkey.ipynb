# %% [markdown]
# ## Summary
#
# ### tl;dr
#
# Notes:
# * Valkey is a Linux Foundation Project and was forked from Redis on 2024-03-28
# * Caveat: This is purely a summary of the data that has not been validated from anyone within the community
# * Analysis of contributions to one repo: https://github.com/valkey-io/valkey
#
# Diverse set of contributors from a variety of companies with Amazon and Google employees making the most significant contributions, and no contributions from Redis employees after the fork.
#
# ### After 2024-03-28 Fork (until 2024-08-20):
#
# Known Affiliations - people with >= 5 commits:
# * People: 25 0.3048780487804878 % of people
# * Commits: 324
# * Additions: 70628 0.7876962883654532 % of total additions
# * Deletions: 50099 0.761186319643861 % of total deletions
#
# Other People - people with >= 5 commits:
# * People: 34 0.4146341463414634 % of people
# * Commits: 89
# * Additions: 4520 0.05041042112776588 % of total additions
# * Deletions: 1592 0.0241882796238054 % of total deletions
#
# Totals in dataset of people with >=5 commits:
# * 0.8381067094932191 % of total additions
# * 0.7853745992676664 % of total deletions
#
#
# |People|Company|Commits|Additions|Deletions|
# |:---|:---|:---|:---|:---|
# | 2 | Google | 27 | 40191 | 38406 |
# | 11 | Amazon | 121 | 15072 | 5766 |
# | 34 | None | 89 | 4520 | 1592 |
# | 2 | Alibaba | 6 | 303 | 51 |
# | 2 | ByteDance | 5 | 3913 | 562 |
# | 4 | Huawei | 66 | 3205 | 2764 |
# | 1 | Tencent Cloud | 46 | 1690 | 703 |
# | 1 | Intel | 10 | 559 | 455 |
# | 1 | Ericsson Software Technology | 35 | 5591 | 1319 |
# | 1 | @gnet-io | 8 | 104 | 73 |

# %%
from pprint import pprint
import collections
import pandas as pd
import pickle

# Pickle files generated by this script:
# https://github.com/geekygirldawn/project-api-metrics/blob/main/scripts/commits_people.py

people_pickle = 'valkey_people_2024-03-28T00:00:00.000+00:002024-08-20T00:00:00.000+00:00.pkl'

with open(people_pickle, 'rb') as f:
    person_dict = pickle.load(f)
    
len(person_dict)
# Out:
# 82

# %%
people = len(person_dict)
commits = 0
additions = 0
deletions = 0

for key,value in person_dict.items():
    # Normalize company names and use emails to derive some affiliations
    print(key,value)
    if value['company'] == None:
        for email in value['email']:
            if any(x in email.lower() for x in ['redis.com', 'redislabs.com']):
                person_dict[key]['company'] = 'Redis Labs'
            if 'amazon.com' in email:
                person_dict[key]['company'] = 'Amazon'
    elif 'huawei' in value['company'].lower():
        person_dict[key]['company'] = 'Huawei'
    elif 'alibaba' in value['company'].lower():
        person_dict[key]['company'] = 'Alibaba'
    elif any(x in value['company'].lower() for x in ['aws','amazon']):
        person_dict[key]['company'] = 'Amazon'
    
        
    # Get descriptive statistics
    commits = commits + value['commits']
    additions = additions + value['additions']
    deletions = deletions + value['deletions']
    
print("People:", people)
print("Commits:", commits)
print("Additions", additions)
print("Deletions", deletions)
# Out:
# shogo82148 {'email': ['shogo82148@gmail.com'], 'name': 'ICHINOSE Shogo', 'company': '@fuller-inc ', 'additions': 41, 'deletions': 38, 'commits': 1}
# PingXie {'email': ['pingxie@outlook.com', 'pingxie@google.com'], 'name': 'Ping Xie', 'company': 'Google', 'additions': 39434, 'deletions': 37649, 'commits': 26}
# madolson {'email': ['madelyneolson@gmail.com', '34459052+madolson@users.noreply.github.com'], 'name': 'Madelyn Olson', 'company': 'Amazon Web Services', 'additions': 8308, 'deletions': 3604, 'commits': 65}
# pieturin {'email': ['105686771+pieturin@users.noreply.github.com'], 'name': 'Pierre', 'company': 'Amazon Web Services', 'additions': 5, 'deletions': 0, 'commits': 1}
# bentotten {'email': ['59932872+bentotten@users.noreply.github.com'], 'name': None, 'company': None, 'additions': 5, 'deletions': 4, 'commits': 4}
# eliblight {'email': ['eran.liberty@gmail.com'], 'name': 'Eran Liberty', 'company': None, 'additions': 14, 'deletions': 48, 'commits': 5}
# stockholmux {'email': ['kyledvs@amazon.com'], 'name': 'Kyle J. Davis', 'company': '@valkey-io', 'additions': 0, 'deletions': 6, 'commits': 1}
# Rayacoo {'email': ['zisong.cw@alibaba-inc.com'], 'name': None, 'company': '@alibaba', 'additions': 14, 'deletions': 25, 'commits': 2}
# K-Jo {'email': ['pieter@redislabs.com'], 'name': 'Pieter Cailliau', 'company': 'Redis', 'additions': 175, 'deletions': 185, 'commits': 1}
# gabiganam {'email': ['gabiganam@gmail.com'], 'name': 'Gabi Ganam', 'company': 'AWS', 'additions': 7, 'deletions': 0, 'commits': 1}
# jayvdb {'email': ['jayvdb@gmail.com'], 'name': 'John Vandenberg', 'company': '@franklin-ai', 'additions': 137, 'deletions': 96, 'commits': 4}
# uriyage {'email': ['78144248+uriyage@users.noreply.github.com'], 'name': None, 'company': None, 'additions': 2053, 'deletions': 1044, 'commits': 7}
# kukey {'email': ['wei.kukey@gmail.com'], 'name': None, 'company': None, 'additions': 78, 'deletions': 1, 'commits': 1}
# secwall {'email': ['secwall@secwall.me'], 'name': None, 'company': None, 'additions': 1, 'deletions': 0, 'commits': 1}
# dev-jonghoonpark {'email': ['dev@jonghoonpark.com'], 'name': 'jonghoonpark', 'company': None, 'additions': 27, 'deletions': 100, 'commits': 1}
# BCathcart {'email': ['31714723+BCathcart@users.noreply.github.com'], 'name': 'Brennan', 'company': None, 'additions': 18, 'deletions': 7, 'commits': 2}
# pshankinclarke {'email': ['38367844+pshankinclarke@users.noreply.github.com'], 'name': None, 'company': None, 'additions': 3, 'deletions': 1, 'commits': 2}
# pizhenwei {'email': ['p_ace@126.com', 'pizhenwei@bytedance.com'], 'name': 'zhenwei pi', 'company': 'ByteDance', 'additions': 3342, 'deletions': 1, 'commits': 1}
# DarrenJiang13 {'email': ['yjjiang1996@163.com'], 'name': None, 'company': 'Shanghai Jiaotong University', 'additions': 2, 'deletions': 0, 'commits': 1}
# Shivshankar-Reddy {'email': ['shiva.sheri.github@gmail.com'], 'name': 'Shivshankar', 'company': 'Huawei Canada', 'additions': 1581, 'deletions': 1605, 'commits': 32}
# JohnSully {'email': ['john@csquare.ca'], 'name': 'John Sully', 'company': None, 'additions': 10, 'deletions': 1, 'commits': 1}
# nitaicaro {'email': ['42576749+nitaicaro@users.noreply.github.com'], 'name': None, 'company': None, 'additions': 44, 'deletions': 2, 'commits': 4}
# karthyuom {'email': ['karthyuom@gmail.com'], 'name': 'Karthick Ariyaratnam', 'company': 'Huawei Technologies Canada, Co., Ltd.', 'additions': 636, 'deletions': 564, 'commits': 9}
# LiiNen {'email': ['kjeonghoon065@gmail.com'], 'name': 'LiiNen', 'company': 'LINE', 'additions': 122, 'deletions': 69, 'commits': 3}
# barracuda156 {'email': ['vital.had@gmail.com'], 'name': 'Sergey Fedorov', 'company': 'Soochow University', 'additions': 13, 'deletions': 6, 'commits': 1}
# adetunjii {'email': ['45036507+adetunjii@users.noreply.github.com'], 'name': 'Samuel Adetunji', 'company': 'Prunny Technologies', 'additions': 1593, 'deletions': 1585, 'commits': 3}
# pragnesh {'email': ['pg.radadia@gmail.com'], 'name': None, 'company': None, 'additions': 298, 'deletions': 298, 'commits': 1}
# VoletiRam {'email': ['90425341+VoletiRam@users.noreply.github.com'], 'name': None, 'company': None, 'additions': 28, 'deletions': 2, 'commits': 1}
# kyle-yh-kim {'email': ['105247741+kyle-yh-kim@users.noreply.github.com'], 'name': 'Kyle Kim (kimkyle@)', 'company': None, 'additions': 1795, 'deletions': 127, 'commits': 4}
# WM0323 {'email': ['sher0519p@outlook.com'], 'name': 'Sher_Sun', 'company': None, 'additions': 38, 'deletions': 38, 'commits': 4}
# arthurkiller {'email': ['arthurkiller@users.noreply.github.com'], 'name': 'Arthur Lee', 'company': None, 'additions': 25, 'deletions': 4, 'commits': 3}
# 9bany {'email': ['53461381+0del@users.noreply.github.com'], 'name': 'Bany', 'company': None, 'additions': 619, 'deletions': 616, 'commits': 26}
# hpatro {'email': ['harkrisp@amazon.com', 'bunty.hari@gmail.com'], 'name': 'Harkrishn Patro', 'company': '@AWS', 'additions': 749, 'deletions': 393, 'commits': 17}
# mapleFU {'email': ['maplewish117@gmail.com'], 'name': 'mwish', 'company': None, 'additions': 1, 'deletions': 1, 'commits': 1}
# xbasel {'email': ['103044017+xbasel@users.noreply.github.com'], 'name': None, 'company': None, 'additions': 58, 'deletions': 41, 'commits': 1}
# hwware {'email': ['wen.hui.ware@gmail.com'], 'name': 'Wen Hui', 'company': 'Huawei Technologies', 'additions': 934, 'deletions': 541, 'commits': 23}
# guowangy {'email': ['wangyang.guo@intel.com'], 'name': 'Guo Wangyang', 'company': None, 'additions': 91, 'deletions': 31, 'commits': 2}
# Conan-Kudo {'email': ['ngompa13@gmail.com'], 'name': 'Neal Gompa (ニール・ゴンパ)', 'company': '@VelocityLimitless', 'additions': 5, 'deletions': 0, 'commits': 1}
# dmitrypol {'email': ['dmitrypol@users.noreply.github.com'], 'name': 'Dmitry Polyakovsky', 'company': 'Oracle', 'additions': 10948, 'deletions': 10948, 'commits': 4}
# enjoy-binbin {'email': ['binloveplay1314@qq.com'], 'name': 'Binbin', 'company': 'Tencent Cloud', 'additions': 1690, 'deletions': 703, 'commits': 46}
# CharlesChen888 {'email': ['TJ_Chen@outlook.com'], 'name': 'Chen Tianjie', 'company': 'Looking for a job', 'additions': 170, 'deletions': 22, 'commits': 4}
# ouriamzn {'email': ['112880714+ouriamzn@users.noreply.github.com'], 'name': 'Ouri Half', 'company': 'Amazon', 'additions': 20, 'deletions': 26, 'commits': 1}
# vitahlin {'email': ['vitahlin@gmail.com', 'linw1225@gmail.com'], 'name': 'Vitah Lin', 'company': None, 'additions': 144, 'deletions': 57, 'commits': 9}
# jonathanspw {'email': ['jonathan@effecthost.com'], 'name': 'Jonathan Wright', 'company': None, 'additions': 106, 'deletions': 44, 'commits': 1}
# gentcys {'email': ['iamchencong@gmail.com'], 'name': 'Cong Chen', 'company': None, 'additions': 1, 'deletions': 1, 'commits': 1}
# hallmason17 {'email': ['55302632+hallmason17@users.noreply.github.com'], 'name': 'Mason Hall', 'company': 'Humana', 'additions': 1087, 'deletions': 984, 'commits': 1}
# mkdolan {'email': ['mikedolan@gmail.com'], 'name': 'Mike Dolan', 'company': 'The Linux Foundation', 'additions': 6, 'deletions': 0, 'commits': 1}
# wkgcass {'email': ['wkgcass@hotmail.com'], 'name': 'K.G. Wang', 'company': None, 'additions': 16, 'deletions': 3, 'commits': 1}
# eltociear {'email': ['eltociear@gmail.com'], 'name': 'Ikko Eltociear Ashimine', 'company': '@bandism ', 'additions': 1, 'deletions': 1, 'commits': 1}
# artikell {'email': ['739609084@qq.com'], 'name': 'skyfirelee', 'company': 'ByteDance', 'additions': 571, 'deletions': 561, 'commits': 4}
# lipzhu {'email': ['lipeng.zhu@intel.com', 'lipzhu@icloud.com'], 'name': 'Lipeng Zhu', 'company': 'Intel', 'additions': 559, 'deletions': 455, 'commits': 10}
# flowerysong {'email': ['junk+github@flowerysong.com'], 'name': None, 'company': 'University of Michigan', 'additions': 4, 'deletions': 8, 'commits': 1}
# murphyjacob4 {'email': ['jkmurphy@google.com'], 'name': 'Jacob Murphy', 'company': 'Google', 'additions': 757, 'deletions': 757, 'commits': 1}
# ranshid {'email': ['88133677+ranshid@users.noreply.github.com'], 'name': None, 'company': 'Amazon Web Services', 'additions': 112, 'deletions': 91, 'commits': 7}
# parthpatel {'email': ['661497+parthpatel@users.noreply.github.com'], 'name': 'Parth', 'company': None, 'additions': 77, 'deletions': 16, 'commits': 2}
# aiven-sal {'email': ['salvatore.mesoraca@aiven.io'], 'name': 'Salvatore Mesoraca', 'company': '@aiven', 'additions': 1, 'deletions': 4, 'commits': 1}
# zuiderkwast {'email': ['viktor.soderqvist@est.tech'], 'name': 'Viktor Söderqvist', 'company': 'Ericsson Software Technology', 'additions': 5591, 'deletions': 1319, 'commits': 35}
# srgsanky {'email': ['1890648+srgsanky@users.noreply.github.com'], 'name': 'Sankar', 'company': None, 'additions': 204, 'deletions': 9, 'commits': 2}
# daniel-house-at-huawei {'email': ['daniel.house@huawei.com'], 'name': None, 'company': None, 'additions': 35, 'deletions': 35, 'commits': 2}
# gmbnomis {'email': ['gmbnomis@users.noreply.github.com'], 'name': None, 'company': None, 'additions': 2, 'deletions': 5, 'commits': 1}
# mikelolasagasti {'email': ['mikel@olasagasti.info'], 'name': 'Mikel Olasagasti Uranga', 'company': None, 'additions': 2, 'deletions': 2, 'commits': 1}
# Virusuki {'email': ['namuk2004@naver.com', 'namuk87.kim@samsung.com'], 'name': 'NAM UK KIM', 'company': 'S-Core (Samsung affiliates)', 'additions': 7, 'deletions': 9, 'commits': 2}
# tommorris {'email': ['tom@tommorris.org'], 'name': 'Tom Morris', 'company': None, 'additions': 1, 'deletions': 1, 'commits': 1}
# Wenwen-Chen {'email': ['wenwen.chen@samsung.com'], 'name': None, 'company': 'Samsung Electronics', 'additions': 33, 'deletions': 36, 'commits': 1}
# roshkhatri {'email': ['117414976+roshkhatri@users.noreply.github.com'], 'name': 'Roshan Khatri', 'company': None, 'additions': 767, 'deletions': 113, 'commits': 7}
# Yury-Fridlyand {'email': ['yury.fridlyand@improving.com'], 'name': None, 'company': None, 'additions': 41, 'deletions': 3, 'commits': 1}
# luoos {'email': ['luojunmoo@gmail.com'], 'name': 'Jun Luo', 'company': None, 'additions': 11, 'deletions': 11, 'commits': 1}
# AlanZhang1204 {'email': ['1014810735@qq.com'], 'name': None, 'company': 'Huawei', 'additions': 54, 'deletions': 54, 'commits': 2}
# soloestoy {'email': ['zhaozhao.zz@alibaba-inc.com'], 'name': 'zhaozhao.zz', 'company': 'Alibaba', 'additions': 289, 'deletions': 26, 'commits': 4}
# simkusr {'email': ['rolandas@simkus.io'], 'name': 'Rolandas Šimkus', 'company': 'simkus.io', 'additions': 38, 'deletions': 38, 'commits': 2}
# naglera {'email': ['58042354+naglera@users.noreply.github.com'], 'name': 'Amit Nagler', 'company': 'AWS', 'additions': 2844, 'deletions': 407, 'commits': 8}
# poiuj {'email': ['1099644+poiuj@users.noreply.github.com'], 'name': None, 'company': 'AWS', 'additions': 193, 'deletions': 40, 'commits': 2}
# arpitansu {'email': ['arpit.pandey05@gmail.com'], 'name': 'Arpit Pandey', 'company': None, 'additions': 1, 'deletions': 1, 'commits': 1}
# KarthikSubbarao {'email': ['karthikrs2021@gmail.com'], 'name': None, 'company': None, 'additions': 77, 'deletions': 78, 'commits': 2}
# josiahcarlson {'email': ['josiah.carlson@gmail.com'], 'name': 'Josiah Carlson', 'company': None, 'additions': 657, 'deletions': 49, 'commits': 1}
# TedLyngmo {'email': ['ted@lyncon.se'], 'name': 'Ted Lyngmo', 'company': None, 'additions': 4, 'deletions': 1, 'commits': 1}
# bjosv {'email': ['bjorn.a.svensson@est.tech'], 'name': 'Björn Svensson', 'company': '@Ericsson ', 'additions': 80, 'deletions': 53, 'commits': 2}
# aveminus {'email': ['siddharthmondal@gmail.com', 'sid@aveminus.com'], 'name': 'Siddhartha Sankar Mondal', 'company': None, 'additions': 2, 'deletions': 2, 'commits': 2}
# iandouglas {'email': ['ian.douglas@iandouglas.com'], 'name': 'w. ian douglas', 'company': 'iandouglas.com', 'additions': 2, 'deletions': 2, 'commits': 1}
# panjf2000 {'email': ['i@andypan.me'], 'name': 'Andy Pan', 'company': '@gnet-io', 'additions': 104, 'deletions': 73, 'commits': 8}
# PatrickJS {'email': ['github@gdi2290.com', 'github@patrickjs.com'], 'name': 'PatrickJS', 'company': '@kunai-consulting', 'additions': 15, 'deletions': 0, 'commits': 1}
# daniel-house {'email': ['76451671+daniel-house@users.noreply.github.com'], 'name': 'Daniel House @ Seeking Opportunities', 'company': 'Seeking Opportunities', 'additions': 36, 'deletions': 36, 'commits': 3}
# People: 82
# Commits: 454
# Additions 89664
# Deletions 65817

# %%
for key,value in person_dict.items():
    if (value['commits'] >= 5) and (value['company'] == None):
        print(key,value)
        
# Note: Unaffiliated after Aug 2023: https://www.linkedin.com/in/9bany/
# Out:
# eliblight {'email': ['eran.liberty@gmail.com'], 'name': 'Eran Liberty', 'company': None, 'additions': 14, 'deletions': 48, 'commits': 5}
# uriyage {'email': ['78144248+uriyage@users.noreply.github.com'], 'name': None, 'company': None, 'additions': 2053, 'deletions': 1044, 'commits': 7}
# 9bany {'email': ['53461381+0del@users.noreply.github.com'], 'name': 'Bany', 'company': None, 'additions': 619, 'deletions': 616, 'commits': 26}
# vitahlin {'email': ['vitahlin@gmail.com', 'linw1225@gmail.com'], 'name': 'Vitah Lin', 'company': None, 'additions': 144, 'deletions': 57, 'commits': 9}
# roshkhatri {'email': ['117414976+roshkhatri@users.noreply.github.com'], 'name': 'Roshan Khatri', 'company': None, 'additions': 767, 'deletions': 113, 'commits': 7}

# %%
# Manual Fixes
person_dict['roshkhatri']['company'] = 'Amazon' # https://www.linkedin.com/in/roshan-vivek-khatri-a403a8193/
person_dict['uriyage']['company'] = 'Amazon' # https://valkey.io/blog/unlock-one-million-rps/
person_dict['eliblight']['company'] = 'Amazon' # https://www.linkedin.com/in/eran-liberty-b7317b4/

# %%
import collections

org_people = 0
org_commits = 0
org_additions = 0
org_deletions = 0

other_people = 0
other_commits = 0
other_additions = 0
other_deletions = 0

org_dict = collections.defaultdict(dict)

for key,value in person_dict.items():
    try:
        org_dict[value['company']]['commits'] = org_dict[value['company']]['commits'] + value['commits']
        org_dict[value['company']]['additions'] = org_dict[value['company']]['additions'] + value['additions']
        org_dict[value['company']]['deletions'] = org_dict[value['company']]['deletions'] + value['deletions']
        org_dict[value['company']]['people'].append(key)
    except:
        org_dict[value['company']]['commits'] = value['commits']
        org_dict[value['company']]['additions'] = value['additions']
        org_dict[value['company']]['deletions'] = value['deletions']
        org_dict[value['company']]['people'] = [key]

        
# Make it easy for the print statements to be copied into a Markdown table
print('|People|Company|Commits|Additions|Deletions|')
print('|:---|:---|:---|:---|:---|')

for key,value in org_dict.items():
    if value['commits'] >= 5:
        if key != None:
            org_people = org_people + len(value['people'])
            org_commits = org_commits + value['commits']
            org_additions = org_additions + value['additions']
            org_deletions = org_deletions + value['deletions']
        else:
            other_people = other_people + len(value['people'])
            other_commits = other_commits + value['commits']
            other_additions = other_additions + value['additions']
            other_deletions = other_deletions + value['deletions']
        print('|', len(value['people']),'|', key, '|', value['commits'],'|', value['additions'],'|', value['deletions'],'|')

print("\nKnown Affiliations - people with >= 5 commits:", "\n* People:", org_people, org_people/people, "% of people")
print("* Commits:", org_commits)
print("* Additions:", org_additions, org_additions/additions, "% of total additions")
print("* Deletions:", org_deletions, org_deletions/deletions, "% of total deletions")

print("\nOther People - people with >= 5 commits:", "\n* People:", other_people, other_people/people, "% of people")
print("* Commits:", other_commits)
print("* Additions:", other_additions, other_additions/additions, "% of total additions")
print("* Deletions:", other_deletions, other_deletions/deletions, "% of total deletions")
      
print("\nTotals in dataset of people with >=5 commits:")
print('*', (other_additions + org_additions)/additions, "% of total additions")
print('*', (other_deletions + org_deletions)/deletions, "% of total deletions")
# Out:
# |People|Company|Commits|Additions|Deletions|
# |:---|:---|:---|:---|:---|
# | 2 | Google | 27 | 40191 | 38406 |
# | 11 | Amazon | 121 | 15072 | 5766 |
# | 34 | None | 89 | 4520 | 1592 |
# | 2 | Alibaba | 6 | 303 | 51 |
# | 2 | ByteDance | 5 | 3913 | 562 |
# | 4 | Huawei | 66 | 3205 | 2764 |
# | 1 | Tencent Cloud | 46 | 1690 | 703 |
# | 1 | Intel | 10 | 559 | 455 |
# | 1 | Ericsson Software Technology | 35 | 5591 | 1319 |
# | 1 | @gnet-io | 8 | 104 | 73 |
#
# Known Affiliations - people with >= 5 commits:
# * People: 25 0.3048780487804878 % of people
# * Commits: 324
# * Additions: 70628 0.7876962883654532 % of total additions
# * Deletions: 50099 0.761186319643861 % of total deletions
#
# Other People - people with >= 5 commits:
# * People: 34 0.4146341463414634 % of people
# * Commits: 89
# * Additions: 4520 0.05041042112776588 % of total additions
# * Deletions: 1592 0.0241882796238054 % of total deletions
#
# Totals in dataset of people with >=5 commits:
# * 0.8381067094932191 % of total additions
# * 0.7853745992676664 % of total deletions
