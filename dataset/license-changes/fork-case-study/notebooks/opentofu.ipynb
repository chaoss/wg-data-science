# %% [markdown]
# # Summary
#
# ## After 2023-09-05 fork until 2024-09-05
#
# |People|Company|Commits|Additions|Addition%|Deletions|Deletion%|
# |:---|:---|:---|:---|:---|:---|:---|
# | 1 | Chainguard | 6 | 266 | 0.17% | 93 | 0.10% |
# | 3 | Harness | 17 | 2948 | 1.85% | 366 | 0.40% |
# | 6 | Env0 | 99 | 26507 | 16.61% | 12248 | 13.23% |
# | 8 | Spacelift | 305 | 81271 | 50.91% | 59111 | 63.87% |
# | 1 | @claranet | 6 | 118 | 0.07% | 20 | 0.02% |
# | 1 | @Cooby-inc | 5 | 72 | 0.05% | 69 | 0.07% |
# | 1 | Hangzhou Dianzi University | 6 | 891 | 0.56% | 242 | 0.26% |
# | 3 | Red Hat | 15 | 1605 | 1.01% | 159 | 0.17% |
# | 1 | @OpenTofu | 44 | 12350 | 7.74% | 3373 | 3.64% |
# | 1 | @lessops  | 6 | 2017 | 1.26% | 226 | 0.24% |
# | 1 | @nvdnc | 5 | 68 | 0.04% | 11 | 0.01% |
#
# Companies with >= 5 commits:
# * People: 27 0.21428571428571427 % of people employed at 11 companies
# * Commits: 514
# * Additions: 128113 0.8026074263411456 % of total additions
# * Deletions: 75918 0.8203360527311038 % of total deletions

# %%
from pprint import pprint
import collections
import pandas as pd
import pickle

# Pickle files generated by this script:
# https://github.com/geekygirldawn/project-api-metrics/blob/main/scripts/commits_people.py

people_pickle = '../data-files/opentofu_people_2023-09-05T00:00:00.000+00:002024-09-05T00:00:00.000+00:00.pkl'

with open(people_pickle, 'rb') as f:
    person_dict = pickle.load(f)
    
len(person_dict)
# Out:
# 126

# %%
people = len(person_dict)
commits = 0
additions = 0
deletions = 0

for key,value in person_dict.items():
    # Normalize company names and use emails to derive some affiliations
    print(key,value)
    if value['company'] == None:
        for email in value['email']:
            if 'harness.io' in email:
                person_dict[key]['company'] = 'Harness'
            elif 'chainguard.dev' in email:
                person_dict[key]['company'] = 'Chainguard'
            elif 'spacelift.io' in email:
                person_dict[key]['company'] = 'Spacelift'
    elif 'env0' in value['company'].lower():
        person_dict[key]['company'] = 'Env0'
    elif 'spacelift' in value['company'].lower():
        person_dict[key]['company'] = 'Spacelift'

        
        
    # Get descriptive statistics
    commits = commits + value['commits']
    additions = additions + value['additions']
    deletions = deletions + value['deletions']
    
print("People:", people)
print("Commits:", commits)
print("Additions", additions)
print("Deletions", deletions)
# Out:
# Hefeweizen {'deletions': 1, 'name': None, 'commits': 1, 'company': None, 'email': ['jmales@gmail.com'], 'additions': 1}
# A-N-uraag {'deletions': 1, 'name': 'Anuraag Marapally', 'commits': 1, 'company': None, 'email': ['47111459+A-N-uraag@users.noreply.github.com'], 'additions': 1}
# Kazzhar {'deletions': 10, 'name': 'Karthik Nayak', 'commits': 2, 'company': None, 'email': ['76555721+Kazzhar@users.noreply.github.com'], 'additions': 572}
# eduzgun {'deletions': 33, 'name': 'Emre Duzgun', 'commits': 4, 'company': None, 'email': ['100037959+eduzgun@users.noreply.github.com'], 'additions': 148}
# jay-dee7 {'deletions': 22, 'name': 'Jasdeep Singh', 'commits': 7, 'company': None, 'email': ['jasdeepsingh.uppal@gmail.com', 'me@jsdp.dev'], 'additions': 17}
# StephanHCB {'deletions': 4, 'name': 'Stephan B.', 'commits': 2, 'company': None, 'email': ['sbs_github_u43a@packetloss.de'], 'additions': 6028}
# jonjohnsonjr {'deletions': 93, 'name': 'Jon Johnson', 'commits': 6, 'company': 'Chainguard', 'email': ['jon.johnson@chainguard.dev', 'jonjohnsonjr@gmail.com'], 'additions': 266}
# allofthesepeople {'deletions': 0, 'name': 'Roger Simms', 'commits': 1, 'company': 'Harness', 'email': ['roger.simms@gmail.com', 'roger.simms@harness.io'], 'additions': 54}
# jakubabrzy {'deletions': 5, 'name': None, 'commits': 1, 'company': None, 'email': ['125285541+jakubabrzy@users.noreply.github.com'], 'additions': 1}
# coderwander {'deletions': 1061, 'name': None, 'commits': 3, 'company': None, 'email': ['166724773+coderwander@users.noreply.github.com'], 'additions': 1314}
# Evi1Pumpkin {'deletions': 1488, 'name': 'Ronny Orot', 'commits': 23, 'company': None, 'email': ['ronny.orot@gmail.com'], 'additions': 12137}
# jenia {'deletions': 1, 'name': 'Evgeniy Ivlev', 'commits': 1, 'company': None, 'email': ['jenia.ivlev@gmail.com'], 'additions': 1}
# NathanBaulch {'deletions': 410, 'name': 'Nathan Baulch', 'commits': 1, 'company': None, 'email': ['nathan.baulch@gmail.com'], 'additions': 410}
# tarruda {'deletions': 27, 'name': 'Thiago Padilha', 'commits': 3, 'company': None, 'email': ['thiago@padilha.cc'], 'additions': 142}
# roni-frantchi {'deletions': 49, 'name': 'Roni Frantchi', 'commits': 8, 'company': 'Env0', 'email': ['roni-frantchi@users.noreply.github.com'], 'additions': 667}
# cube2222 {'deletions': 2169, 'name': 'Kuba Martin', 'commits': 85, 'company': None, 'email': ['kubam@spacelift.io', 'jakub.wit.martin@gmail.com'], 'additions': 2440}
# damianstasik {'deletions': 3924, 'name': 'Damian Stasik', 'commits': 6, 'company': None, 'email': ['920747+damianstasik@users.noreply.github.com'], 'additions': 4272}
# Yantrio {'deletions': 32302, 'name': 'James Humphries', 'commits': 45, 'company': None, 'email': ['James@james-humphries.co.uk', 'james@james-humphries.co.uk', 'jamesh@spacelift.io'], 'additions': 25309}
# pdecat {'deletions': 20, 'name': 'Patrick Decat', 'commits': 6, 'company': '@claranet', 'email': ['pdecat@gmail.com'], 'additions': 118}
# tsprlng {'deletions': 11, 'name': 'Tom Spurling', 'commits': 1, 'company': None, 'email': ['tom@tspurling.co.uk'], 'additions': 10}
# kazimierzbudzyk {'deletions': 1, 'name': None, 'commits': 1, 'company': None, 'email': ['62395833+kazimierzbudzyk@users.noreply.github.com'], 'additions': 1}
# IgnorantSapient {'deletions': 13, 'name': 'Ashwin Annamalai', 'commits': 3, 'company': None, 'email': ['4549937+IgnorantSapient@users.noreply.github.com'], 'additions': 30}
# MaximilianoAguirre {'deletions': 2, 'name': 'Maximiliano Aguirre', 'commits': 2, 'company': None, 'email': ['maximiliano.aguirre@outlook.es'], 'additions': 2}
# SaiCharanReddyAdla {'deletions': 20, 'name': 'SaiCharanReddyAdla', 'commits': 2, 'company': None, 'email': ['163337878+SaiCharanReddyAdla@users.noreply.github.com'], 'additions': 49}
# serdardalgic {'deletions': 323, 'name': 'Serdar Dalgıç', 'commits': 5, 'company': None, 'email': ['serdardalgic@users.noreply.github.com'], 'additions': 1766}
# jiawei-hong {'deletions': 69, 'name': 'Jiawei', 'commits': 5, 'company': '@Cooby-inc', 'email': ['zxc37984@gmail.com'], 'additions': 72}
# j4ng5y {'deletions': 1, 'name': 'Jordan Gregory', 'commits': 1, 'company': '@PayNearMe', 'email': ['44218998+j4ng5y@users.noreply.github.com'], 'additions': 1}
# tony21921 {'deletions': 3, 'name': 'Tony Yin', 'commits': 1, 'company': None, 'email': ['changyu.yin@outlook.com'], 'additions': 33}
# tataranovich {'deletions': 0, 'name': 'Andrey Tataranovich', 'commits': 1, 'company': None, 'email': ['tataranovich@gmail.com'], 'additions': 2}
# brikis98 {'deletions': 1, 'name': 'Yevgeniy Brikman', 'commits': 1, 'company': '@gruntwork-io ', 'email': ['brikis98@users.noreply.github.com'], 'additions': 2}
# michiboo {'deletions': 1, 'name': None, 'commits': 1, 'company': None, 'email': ['chanmickyyun@gmail.com'], 'additions': 1}
# sanskruti-shahu {'deletions': 88, 'name': 'Sanskruti Shahu', 'commits': 2, 'company': None, 'email': ['76054960+sanskruti-shahu@users.noreply.github.com'], 'additions': 594}
# yaronya {'deletions': 6461, 'name': 'Yaron Yarimi', 'commits': 10, 'company': 'Env0', 'email': ['yaronya@users.noreply.github.com'], 'additions': 6520}
# eltociear {'deletions': 9, 'name': 'Ikko Eltociear Ashimine', 'commits': 3, 'company': '@bandism ', 'email': ['ashimine_ikko_bp@tenso.com', 'eltociear@gmail.com'], 'additions': 9}
# julienlevasseur {'deletions': 2497, 'name': 'Julien Levasseur', 'commits': 1, 'company': None, 'email': ['julien.levasseur@free.fr'], 'additions': 2497}
# jessiepuls {'deletions': 1, 'name': 'Jessie Puls', 'commits': 1, 'company': None, 'email': ['jessie.puls@testdouble.com'], 'additions': 1}
# 1garo {'deletions': 70, 'name': None, 'commits': 1, 'company': None, 'email': ['44412643+1garo@users.noreply.github.com'], 'additions': 61}
# nemobis {'deletions': 1, 'name': None, 'commits': 1, 'company': '@relex', 'email': ['federicoleva@tiscali.it'], 'additions': 1}
# mermoldy {'deletions': 1, 'name': 'Serhii Babak', 'commits': 1, 'company': '@Scalr', 'email': ['serhii.babak@protonmail.com'], 'additions': 88}
# maheshrijal {'deletions': 4, 'name': 'Mahesh Rijal', 'commits': 2, 'company': None, 'email': ['62394512+maheshrjl@users.noreply.github.com'], 'additions': 4}
# wojciech12 {'deletions': 3, 'name': 'Wojciech Barczyński', 'commits': 3, 'company': '@spacelift-io', 'email': ['30651937+wojciech12@users.noreply.github.com'], 'additions': 749}
# avorima {'deletions': 19, 'name': 'Mario Valderrama', 'commits': 1, 'company': '@ionos-cloud ', 'email': ['15158349+avorima@users.noreply.github.com'], 'additions': 218}
# Ericwww {'deletions': 242, 'name': 'Syasusu', 'commits': 6, 'company': 'Hangzhou Dianzi University', 'email': ['syasusu@163.com'], 'additions': 891}
# Cadienvan {'deletions': 3, 'name': 'Michael Di Prisco', 'commits': 2, 'company': None, 'email': ['Cadienvan@users.noreply.github.com'], 'additions': 3}
# dependabot[bot] {'deletions': 19, 'name': None, 'commits': 4, 'company': None, 'email': ['49699333+dependabot[bot]@users.noreply.github.com'], 'additions': 26}
# nikitabarskov {'deletions': 0, 'name': 'Nikita Barskov', 'commits': 2, 'company': '@volur-ai', 'email': ['nbarskov@gmail.com'], 'additions': 126}
# asbiin {'deletions': 14, 'name': 'Alexis Saettler', 'commits': 2, 'company': '@monicahq ', 'email': ['alexis@saettler.org'], 'additions': 18}
# adrianmester {'deletions': 13, 'name': 'Adrian Mester', 'commits': 1, 'company': None, 'email': ['33199+adrianmester@users.noreply.github.com'], 'additions': 9}
# Roma36 {'deletions': 4463, 'name': 'Roman Grinovski', 'commits': 4, 'company': '@spacelift-io', 'email': ['roman.grinovski@gmail.com'], 'additions': 4718}
# marcelfranca {'deletions': 1, 'name': 'Marcel França', 'commits': 1, 'company': None, 'email': ['35463219+marcelfranca@users.noreply.github.com'], 'additions': 2}
# jnsgruk {'deletions': 0, 'name': 'Jon Seager', 'commits': 2, 'company': '@canonical', 'email': ['jon@sgrs.uk'], 'additions': 28}
# ipolyzos {'deletions': 22, 'name': 'Ioannis Polyzos', 'commits': 2, 'company': None, 'email': ['git@ipolyzos.com'], 'additions': 45}
# DicsyDel {'deletions': 0, 'name': 'I S', 'commits': 2, 'company': None, 'email': ['igor@scalr.com'], 'additions': 78}
# l-with {'deletions': 4, 'name': None, 'commits': 1, 'company': None, 'email': ['l.github.com@with.de'], 'additions': 114}
# thschue {'deletions': 0, 'name': 'Thomas Schuetz', 'commits': 1, 'company': None, 'email': ['38893055+thschue@users.noreply.github.com'], 'additions': 18}
# mtarsel {'deletions': 2, 'name': 'Mick Tarsel', 'commits': 3, 'company': 'Red Hat', 'email': ['mtarsel@gmail.com'], 'additions': 12}
# dotemacs {'deletions': 2, 'name': 'Александар Симић', 'commits': 1, 'company': None, 'email': ['a@repl.ist'], 'additions': 2}
# namgyalangmo {'deletions': 1275, 'name': None, 'commits': 2, 'company': None, 'email': ['75657887+namgyalangmo@users.noreply.github.com'], 'additions': 4439}
# ChihweiLHBird {'deletions': 1, 'name': 'Zhiwei', 'commits': 1, 'company': '@akamai @linode', 'email': ['zhi.wei.liang@outlook.com', 'chihwei.public@outlook.com'], 'additions': 11}
# joaocc {'deletions': 10, 'name': 'Joao C Costa', 'commits': 1, 'company': 'KIT-AR Ltd', 'email': ['joaocc@users.noreply.github.com'], 'additions': 8}
# wyardley {'deletions': 2, 'name': 'Will Yardley', 'commits': 1, 'company': None, 'email': ['wyardley@users.noreply.github.com'], 'additions': 2}
# siddharthasonker95 {'deletions': 301, 'name': 'Siddhartha Sonker', 'commits': 11, 'company': 'Harness', 'email': ['158144589+siddharthasonker95@users.noreply.github.com'], 'additions': 1649}
# wrp {'deletions': 1, 'name': 'William Pursell', 'commits': 1, 'company': 'Affirm', 'email': ['william.r.pursell@gmail.com'], 'additions': 1}
# alrs {'deletions': 1293, 'name': 'Lars Lehtonen', 'commits': 31, 'company': None, 'email': ['lars.lehtonen@gmail.com'], 'additions': 803}
# marcinwyszynski {'deletions': 1657, 'name': 'Marcin Wyszynski', 'commits': 14, 'company': '@spacelift-io ', 'email': ['marcin.pixie@gmail.com'], 'additions': 2103}
# jsm222 {'deletions': 1, 'name': 'Jesper Schmitz Mouridsen', 'commits': 1, 'company': None, 'email': ['jesper@schmitz.computer'], 'additions': 1}
# kislerdm {'deletions': 3937, 'name': 'Dmitry Kisler', 'commits': 19, 'company': None, 'email': ['admin@dkisler.com'], 'additions': 4413}
# mbialon {'deletions': 113, 'name': 'Marcin Białoń', 'commits': 11, 'company': None, 'email': ['mbialon@spacelift.io', 'marcin@bialon.net'], 'additions': 1079}
# professorabhay {'deletions': 1, 'name': 'Abhay Gupta ', 'commits': 1, 'company': 'Looking for Job', 'email': ['abhayetwup123@gmail.com'], 'additions': 1}
# ollevche {'deletions': 3373, 'name': 'Oleksandr Levchenkov', 'commits': 44, 'company': '@OpenTofu', 'email': ['ollevche@gmail.com'], 'additions': 12350}
# cam72cam {'deletions': 14480, 'name': 'Christian Mesh', 'commits': 137, 'company': None, 'email': ['christianmesh1@gmail.com', 'cam72cam@gmail.com'], 'additions': 40601}
# testwill {'deletions': 0, 'name': 'guoguangwu', 'commits': 1, 'company': None, 'email': ['guoguangwu@magic-shield.com', 'guoguangwug@gmail.com'], 'additions': 1}
# tomasmik {'deletions': 944, 'name': 'Tomas', 'commits': 4, 'company': None, 'email': ['40318863+tomasmik@users.noreply.github.com', 'tomasmik@protonmail.com'], 'additions': 2437}
# virtualroot {'deletions': 226, 'name': 'Alejandro Lazaro', 'commits': 6, 'company': '@lessops ', 'email': ['virtualroot@users.noreply.github.com'], 'additions': 2017}
# rothgar {'deletions': 1885, 'name': 'Justin Garrison', 'commits': 2, 'company': '@SideorLabs', 'email': ['justin@linux.com'], 'additions': 1959}
# haojue {'deletions': 6, 'name': 'HaojueWang', 'commits': 1, 'company': 'IBM', 'email': ['acewhj@gmail.com'], 'additions': 6}
# alex067 {'deletions': 4, 'name': 'Alexandros Panayi', 'commits': 2, 'company': None, 'email': ['panayi067@gmail.com'], 'additions': 4}
# rosvik {'deletions': 1, 'name': 'Johannes Røsvik', 'commits': 1, 'company': '@varianter', 'email': ['j.rosvik@gmail.com'], 'additions': 1}
# pooriaghaedi {'deletions': 1, 'name': 'Pooria Ghaedi', 'commits': 1, 'company': None, 'email': ['36617391+pooriaghaedi@users.noreply.github.com'], 'additions': 211}
# mehhhhhhhhhhhhhhh {'deletions': 11, 'name': 'mise en hache', 'commits': 1, 'company': 'writing tests in exchange for money', 'email': ['137650446+mehhhhhhhhhhhhhhh@users.noreply.github.com'], 'additions': 10}
# jjshanks {'deletions': 69, 'name': 'Joshua Shanks', 'commits': 3, 'company': 'Sentilink', 'email': ['jjshanks@gmail.com'], 'additions': 56}
# jpitlor {'deletions': 0, 'name': 'Jordan Pitlor', 'commits': 1, 'company': 'AvaSure / @cfcc', 'email': ['jpitlor@gmail.com', 'jordan@pitlor.dev'], 'additions': 6}
# desmaraisp {'deletions': 3, 'name': 'Philippe Desmarais', 'commits': 1, 'company': '@telus-health', 'email': ['philippe.desmarais0trash@gmail.com'], 'additions': 7}
# siddharthasonker {'deletions': 61, 'name': 'Siddhartha Sonker', 'commits': 1, 'company': None, 'email': ['34684647+siddharthasonker@users.noreply.github.com'], 'additions': 159}
# maksym-nazarenko {'deletions': 15, 'name': 'Maksym', 'commits': 1, 'company': None, 'email': ['maks.nazarenko@gmail.com'], 'additions': 74}
# kmgrime {'deletions': 2, 'name': 'Kjell-Magnus', 'commits': 1, 'company': '@aztekas', 'email': ['kmgrime@gmail.com'], 'additions': 3}
# 7h3-3mp7y-m4n {'deletions': 44, 'name': None, 'commits': 1, 'company': None, 'email': ['115151332+7h3-3mp7y-m4n@users.noreply.github.com'], 'additions': 44}
# denis256 {'deletions': 40, 'name': 'Denis O', 'commits': 1, 'company': None, 'email': ['denis@universal-development.com', 'denis.o@linux.com'], 'additions': 8}
# lfacchinelli {'deletions': 3, 'name': 'Luciano Facchinelli', 'commits': 1, 'company': None, 'email': ['me@lucianofacchinelli.com'], 'additions': 0}
# SypherSP {'deletions': 16, 'name': 'Shashwat Pandey', 'commits': 4, 'company': None, 'email': ['72958686+SypherSP@users.noreply.github.com'], 'additions': 127}
# RLRabinowitz {'deletions': 2744, 'name': 'Arel Rabinowitz', 'commits': 20, 'company': None, 'email': ['30493345+RLRabinowitz@users.noreply.github.com', 'rlrabinowitz2@gmail.com'], 'additions': 4887}
# nilgaar {'deletions': 0, 'name': 'Nil Gallego', 'commits': 1, 'company': 'Red Hat', 'email': ['73447234+nilgaar@users.noreply.github.com', 'github.i0l5z@simplelogin.com'], 'additions': 6}
# boetro {'deletions': 1, 'name': 'Caleb Van Dyke', 'commits': 1, 'company': '@launchflow', 'email': ['caleb@launchflow.com'], 'additions': 25}
# haidong {'deletions': 61, 'name': 'Haidong Ji', 'commits': 2, 'company': None, 'email': ['ji@haidongji.com'], 'additions': 220}
# aimuz {'deletions': 4, 'name': 'aimuz', 'commits': 1, 'company': None, 'email': ['mr.imuz@gmail.com'], 'additions': 0}
# sftim {'deletions': 1, 'name': 'Tim Bannister', 'commits': 1, 'company': '@scalefactory', 'email': ['tim@scalefactory.com', 'tim+github@scalefactory.com'], 'additions': 2}
# axza {'deletions': 1, 'name': 'ALZ', 'commits': 1, 'company': 'University of Rostock', 'email': ['axza@users.noreply.github.com'], 'additions': 1}
# ianaya89 {'deletions': 6, 'name': 'Nacho Anaya', 'commits': 1, 'company': '@Altinity', 'email': ['ignacio.anaya89@gmail.com'], 'additions': 6}
# ash2k {'deletions': 15, 'name': 'Mikhail Mazurskiy', 'commits': 1, 'company': '@gitlabhq', 'email': ['126021+ash2k@users.noreply.github.com'], 'additions': 12}
# bunniseng {'deletions': 24, 'name': 'David Sims', 'commits': 6, 'company': None, 'email': ['155123017+bunniseng@users.noreply.github.com'], 'additions': 251}
# lettucemode {'deletions': 8, 'name': 'lettucemode', 'commits': 2, 'company': None, 'email': ['2knowindeed@gmail.com'], 'additions': 81}
# Andrew-Hayes {'deletions': 65, 'name': 'Andy Hayes', 'commits': 5, 'company': 'Harness', 'email': ['andrew.hayes@harness.io'], 'additions': 1245}
# eranelbaz {'deletions': 1505, 'name': 'Elbaz', 'commits': 37, 'company': 'Env0', 'email': ['eranelbaz97+github@gmail.com'], 'additions': 2295}
# SweetGeneral {'deletions': 0, 'name': None, 'commits': 1, 'company': None, 'email': ['47386773+SweetGeneral@users.noreply.github.com'], 'additions': 14}
# dragetd {'deletions': 78, 'name': 'Michael G.', 'commits': 1, 'company': 'Software-Developer @setlog', 'email': ['draget@speciesm.net'], 'additions': 78}
# TonyLovesDevOps {'deletions': 1, 'name': 'Tony DevOps', 'commits': 1, 'company': None, 'email': ['868644+TonyLovesDevOps@users.noreply.github.com'], 'additions': 1}
# JonasBak {'deletions': 6, 'name': 'Jonas Bakken', 'commits': 2, 'company': None, 'email': ['jonasbakken@protonmail.com'], 'additions': 146}
# rdhar {'deletions': 1, 'name': 'Rishav Dhar', 'commits': 1, 'company': '@Tucows', 'email': ['19497993+rdhar@users.noreply.github.com'], 'additions': 1}
# mikelolasagasti {'deletions': 157, 'name': 'Mikel Olasagasti Uranga', 'commits': 11, 'company': None, 'email': ['mikel@olasagasti.info'], 'additions': 1587}
# rpoovey {'deletions': 2, 'name': 'Russell Poovey', 'commits': 1, 'company': None, 'email': ['09.our_seekers@icloud.com'], 'additions': 2}
# andrewhertog {'deletions': 19, 'name': 'Andrew den Hertog', 'commits': 1, 'company': '@SMARTeacher ', 'email': ['andrew@denhertog.ca'], 'additions': 15}
# parrotmac {'deletions': 11, 'name': 'Isaac Parker', 'commits': 5, 'company': '@nvdnc', 'email': ['parrotmac@gmail.com'], 'additions': 68}
# hrboyceiii {'deletions': 8, 'name': None, 'commits': 2, 'company': None, 'email': ['hrboyceiii@users.noreply.github.com'], 'additions': 8}
# yindia {'deletions': 116, 'name': 'Yuvraj', 'commits': 3, 'company': None, 'email': ['evalsocket@gmail.com'], 'additions': 223}
# oprudkyi {'deletions': 5, 'name': 'Oleksii Prudkyi', 'commits': 1, 'company': None, 'email': ['oprudkyi@users.noreply.github.com'], 'additions': 34}
# bvand {'deletions': 6, 'name': 'Brian Vander Schaaf', 'commits': 1, 'company': None, 'email': ['6099457+bvand@users.noreply.github.com'], 'additions': 29}
# misha-slyusarev {'deletions': 5, 'name': 'Mikhail Sliusarev', 'commits': 1, 'company': None, 'email': ['mik3weider@gmail.com'], 'additions': 15}
# cgetzen {'deletions': 1, 'name': 'Charlie Getzen', 'commits': 1, 'company': 'Bolt', 'email': ['charliegetzenlc@gmail.com'], 'additions': 1}
# nsballmann {'deletions': 1, 'name': 'Nils Ballmann', 'commits': 1, 'company': 'Siemens', 'email': ['45712604+nsballmann@users.noreply.github.com'], 'additions': 2}
# edualb {'deletions': 9, 'name': None, 'commits': 1, 'company': None, 'email': ['39157101+edualb@users.noreply.github.com'], 'additions': 26}
# alexott {'deletions': 1745, 'name': 'Alex Ott', 'commits': 3, 'company': "Alex Ott's Consulting", 'email': ['alexott@gmail.com'], 'additions': 86}
# luis-giraldo {'deletions': 30, 'name': 'Luis Giraldo', 'commits': 2, 'company': '@sonatype ', 'email': ['60015362+luis-giraldo@users.noreply.github.com'], 'additions': 30}
# Jake-Mok-Nelson {'deletions': 0, 'name': 'Jake Nelson', 'commits': 2, 'company': None, 'email': ['Jake-Mok-Nelson@users.noreply.github.com'], 'additions': 33}
# chenzejun {'deletions': 118, 'name': 'chenzj', 'commits': 9, 'company': None, 'email': ['tibazq@gmail.com'], 'additions': 844}
# chpl {'deletions': 1, 'name': 'Chaim Platonov', 'commits': 1, 'company': 'Env0', 'email': ['chaim.platonov@gmail.com', 'chaim.platonov@env0.com'], 'additions': 1}
# thumperward {'deletions': 10, 'name': 'Chris Cunningham', 'commits': 3, 'company': None, 'email': ['therealchriscunningham@outlook.com'], 'additions': 56}
# People: 126
# Commits: 733
# Additions 159621
# Deletions 92545

# %%
for key,value in person_dict.items():
    if (value['commits'] >= 5) and (value['company'] == None):
        print(key,value)
# Out:
# jay-dee7 {'deletions': 22, 'name': 'Jasdeep Singh', 'commits': 7, 'company': None, 'email': ['jasdeepsingh.uppal@gmail.com', 'me@jsdp.dev'], 'additions': 17}
# Evi1Pumpkin {'deletions': 1488, 'name': 'Ronny Orot', 'commits': 23, 'company': None, 'email': ['ronny.orot@gmail.com'], 'additions': 12137}
# damianstasik {'deletions': 3924, 'name': 'Damian Stasik', 'commits': 6, 'company': None, 'email': ['920747+damianstasik@users.noreply.github.com'], 'additions': 4272}
# serdardalgic {'deletions': 323, 'name': 'Serdar Dalgıç', 'commits': 5, 'company': None, 'email': ['serdardalgic@users.noreply.github.com'], 'additions': 1766}
# alrs {'deletions': 1293, 'name': 'Lars Lehtonen', 'commits': 31, 'company': None, 'email': ['lars.lehtonen@gmail.com'], 'additions': 803}
# kislerdm {'deletions': 3937, 'name': 'Dmitry Kisler', 'commits': 19, 'company': None, 'email': ['admin@dkisler.com'], 'additions': 4413}
# cam72cam {'deletions': 14480, 'name': 'Christian Mesh', 'commits': 137, 'company': None, 'email': ['christianmesh1@gmail.com', 'cam72cam@gmail.com'], 'additions': 40601}
# RLRabinowitz {'deletions': 2744, 'name': 'Arel Rabinowitz', 'commits': 20, 'company': None, 'email': ['30493345+RLRabinowitz@users.noreply.github.com', 'rlrabinowitz2@gmail.com'], 'additions': 4887}
# bunniseng {'deletions': 24, 'name': 'David Sims', 'commits': 6, 'company': None, 'email': ['155123017+bunniseng@users.noreply.github.com'], 'additions': 251}
# mikelolasagasti {'deletions': 157, 'name': 'Mikel Olasagasti Uranga', 'commits': 11, 'company': None, 'email': ['mikel@olasagasti.info'], 'additions': 1587}
# chenzejun {'deletions': 118, 'name': 'chenzj', 'commits': 9, 'company': None, 'email': ['tibazq@gmail.com'], 'additions': 844}

# %%
# Manual Fixes
person_dict['Evi1Pumpkin']['company'] = 'Env0' # https://www.linkedin.com/in/ronny-orot-0b8359104/
person_dict['damianstasik']['company'] = 'Spacelift' #https://www.linkedin.com/in/damianstasik/
person_dict['cam72cam']['company'] = 'Spacelift' # https://sessionize.com/christian-mesh/
person_dict['RLRabinowitz']['company'] = 'Env0' # https://www.linkedin.com/in/arel-rabinowitz-a95285179/
person_dict['mikelolasagasti']['company'] = 'Red Hat'# https://www.linkedin.com/in/molasagasti/

# %%
import collections

org_people = 0
org_commits = 0
org_additions = 0
org_deletions = 0

orgs = 0

org_dict = collections.defaultdict(dict)

for key,value in person_dict.items():
    try:
        org_dict[value['company']]['commits'] = org_dict[value['company']]['commits'] + value['commits']
        org_dict[value['company']]['additions'] = org_dict[value['company']]['additions'] + value['additions']
        org_dict[value['company']]['deletions'] = org_dict[value['company']]['deletions'] + value['deletions']
        org_dict[value['company']]['people'].append(key)
    except:
        org_dict[value['company']]['commits'] = value['commits']
        org_dict[value['company']]['additions'] = value['additions']
        org_dict[value['company']]['deletions'] = value['deletions']
        org_dict[value['company']]['people'] = [key]

        
# Make it easy for the print statements to be copied into a Markdown table
print('|People|Company|Commits|Additions|Addition%|Deletions|Deletion%|')
print('|:---|:---|:---|:---|:---|:---|:---|')

for key,value in org_dict.items():
    if value['commits'] >= 5:
        if key != None:
            org_people = org_people + len(value['people'])
            org_commits = org_commits + value['commits']
            org_additions = org_additions + value['additions']
            org_deletions = org_deletions + value['deletions']
            orgs+=1
            add_perc = format(value['additions']/additions, ".2%")
            del_perc = format(value['deletions']/deletions, ".2%")
            print('|', len(value['people']),'|', key, '|', value['commits'],'|', value['additions'],'|',add_perc,'|', value['deletions'],'|',del_perc,'|')

print("\nCompanies with >= 5 commits:", "\n* People:", org_people, org_people/people, "% of people employed at", orgs, "companies")
print("* Commits:", org_commits)
print("* Additions:", org_additions, org_additions/additions, "% of total additions")
print("* Deletions:", org_deletions, org_deletions/deletions, "% of total deletions")
# Out:
# |People|Company|Commits|Additions|Addition%|Deletions|Deletion%|
# |:---|:---|:---|:---|:---|:---|:---|
# | 1 | Chainguard | 6 | 266 | 0.17% | 93 | 0.10% |
# | 3 | Harness | 17 | 2948 | 1.85% | 366 | 0.40% |
# | 6 | Env0 | 99 | 26507 | 16.61% | 12248 | 13.23% |
# | 8 | Spacelift | 305 | 81271 | 50.91% | 59111 | 63.87% |
# | 1 | @claranet | 6 | 118 | 0.07% | 20 | 0.02% |
# | 1 | @Cooby-inc | 5 | 72 | 0.05% | 69 | 0.07% |
# | 1 | Hangzhou Dianzi University | 6 | 891 | 0.56% | 242 | 0.26% |
# | 3 | Red Hat | 15 | 1605 | 1.01% | 159 | 0.17% |
# | 1 | @OpenTofu | 44 | 12350 | 7.74% | 3373 | 3.64% |
# | 1 | @lessops  | 6 | 2017 | 1.26% | 226 | 0.24% |
# | 1 | @nvdnc | 5 | 68 | 0.04% | 11 | 0.01% |
#
# Companies with >= 5 commits:
# * People: 27 0.21428571428571427 % of people employed at 11 companies
# * Commits: 514
# * Additions: 128113 0.8026074263411456 % of total additions
# * Deletions: 75918 0.8203360527311038 % of total deletions
