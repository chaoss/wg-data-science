# %% [markdown]
# ## Summary
#
# ### tl;dr
#
# Notes:
# * Elasticsearch is owned by a company (Elastic) and was relicensed to a non-oss license on 2021-02-03.
# * On 2024-08-29, Elastic announced that it would also be licensed under the open source AGPL in addition to the SSPL and Elastic License.
# * Caveat: This is purely a summary of the data that has not been validated from anyone within the community.
# * Analysis of contributions to one repo: https://github.com/elastic/elasticsearch
#
# Elasticsearch has always been dominated by employee contributions. In the 2 years leading up to the relicense, Elastic employees made 97% of additions and 98% of deletions to the code with similar numbers after the relicense.
#
# ### 2 years before relicense (2019-02-03 - 2021-02-03)
#
# Elastic Employees with >= 10 commits:
# * People: 81 15.85% of people
# * Commits: 12311 93.24% of total commits
# * Additions: 2915551 97.35% of total additions
# * Deletions: 1628155 98.32% of total deletions
#
# Non-Employees with >= 10 commits:
# * People: 5 0.98% of people
# * Commits: 123 0.93% of total commits
# * Additions: 5858 0.20% of total additions
# * Deletions: 1460 0.09% of total deletions
#
# Totals in dataset of people with >=10 commits:
# * 97.55% of total additions
# * 98.41% of total deletions
#
# ### 1 Year Before the Relicense (2020-02-03 - 2021-02-03)
#
# Elastic Employees with >= 10 commits:
# * People: 67 21.00% of people
# * Commits: 6477 92.07% of total commits
# * Additions: 1377558 95.80% of total additions
# * Deletions: 623561 96.72% of total deletions
#
# Non-Employees with >= 10 commits:
# * People: 3 0.94% of people
# * Commits: 94 1.34% of total commits
# * Additions: 3855 0.27% of total additions
# * Deletions: 740 0.11% of total deletions
#
# Totals in dataset of people with >=10 commits:
# * 96.06% of total additions
# * 96.83% of total deletions
#
#
# ### 1 Year after the relicense (2021-02-03 - 2022-02-03)
#
# Elastic Employees with >= 10 commits:
# * People: 65 24.16% of people
# * Commits: 5668 91.23% of total commits
# * Additions: 1597988 95.75% of total additions
# * Deletions: 1061154 98.33% of total deletions
#
# Non-Employees with >= 10 commits:
# * People: 2 0.74% of people
# * Commits: 47 0.76% of total commits
# * Additions: 7283 0.44% of total additions
# * Deletions: 2178 0.20% of total deletions
#
# Totals in dataset of people with >=10 commits:
# * 96.19% of total additions
# * 98.53% of total deletions
#
# ### 1 Year Before Adding AGPL (2023-08-29 - 2024-08-29)
#
# Elastic Employees with >= 10 commits:
# * People: 99 36.26% of people
# * Commits: 7616 94.59% of total commits
# * Additions: 2621830 94.61% of total additions
# * Deletions: 1123628 97.24% of total deletions
#
# Non-Employees with >= 10 commits:
# * People: 1 0.37% of people
# * Commits: 11 0.14% of total commits
# * Additions: 326 0.01% of total additions
# * Deletions: 326 0.03% of total deletions
#
# Totals in dataset of people with >=10 commits:
# * 94.62% of total additions
# * 97.27% of total deletions
#
# ### 6 Months after AGPL (2024-08-29 - 2025-02-29)
#
# Elastic Employees with >= 10 commits:
# * People: 92 38.98% of people
# * Commits: 5149 92.24% of total commits
# * Additions: 2997938 88.02% of total additions
# * Deletions: 2299643 74.46% of total deletions
#
# Non-Employees with >= 10 commits:
# * People: 0 0.00% of people
# * Commits: 0 0.00% of total commits
# * Additions: 0 0.00% of total additions
# * Deletions: 0 0.00% of total deletions
#
# Totals in dataset of people with >=10 commits:
# * 88.02% of total additions
# * 74.46% of total deletions

# %% [markdown]
# # 2 Years before the Elastic relicense (2019-02-03 - 2021-02-03)

# %%
from pprint import pprint
import collections
import pandas as pd
import pickle

# Pickle files generated by this script:
# https://github.com/chaoss/wg-data-science/blob/main/dataset/license-changes/fork-case-study/commits_people.py

people_pickle_2y = '../data-files/elasticsearch_people_2019-02-03T00:00:00.000+00:002021-02-03T00:00:00.000+00:00.pkl'

with open(people_pickle_2y, 'rb') as f:
    person_dict_2y = pickle.load(f)

# %%
people = len(person_dict_2y)
commits = 0
additions = 0
deletions = 0

for key,value in person_dict_2y.items():
    if value['company'] == None:
        for email in value['email']:
            if "elastic.co" in email:
                person_dict_2y[key]['company'] = 'Elastic'
    elif "elastic" in value['company'].lower():
        person_dict_2y[key]['company'] = 'Elastic'
        
    # Get descriptive statistics
    commits = commits + value['commits']
    additions = additions + value['additions']
    deletions = deletions + value['deletions']
    
print("People:", people)
print("Commits:", commits)
print("Additions", additions)
print("Deletions", deletions)
# Out:
# People: 511
# Commits: 13203
# Additions 2994822
# Deletions 1655899

# %%
# Before cleanup
for key,value in person_dict_2y.items():
    #print(key,value['commits'])
    try:
        if value['commits'] >= 10:
            if value['company'] != 'Elastic':
                print(key,value)
    except:
        print(key,value)
# Out:
# nik9000 {'company': None, 'name': 'Nik Everett', 'commits': 381, 'additions': 154370, 'deletions': 85475, 'email': ['nik9000@gmail.com']}
# gaobinlong {'company': 'AWS', 'name': 'gaobinlong', 'commits': 55, 'additions': 3522, 'deletions': 618, 'email': ['gbl_long@163.com', 'gbinlong@amazon.com']}
# romseygeek {'company': 'Romsey Software Ltd', 'name': 'Alan Woodward', 'commits': 267, 'additions': 49705, 'deletions': 60397, 'email': ['romseygeek@gmail.com', 'romseygeek@apache.org']}
# astefan {'company': None, 'name': 'Andrei Stefan', 'commits': 132, 'additions': 27860, 'deletions': 8131, 'email': ['astefan@users.noreply.github.com']}
# elasticmachine {'company': None, 'name': 'Elastic Machine', 'commits': 81, 'additions': 27821, 'deletions': 12250, 'email': ['elasticmachine@users.noreply.github.com']}
# valeriy42 {'company': None, 'name': 'Valeriy Khakhutskyy', 'commits': 24, 'additions': 1734, 'deletions': 688, 'email': ['1292899+valeriy42@users.noreply.github.com']}
# ...

# %%
# Manual Fixes
person_dict_2y['nik9000']['company'] = 'Elastic' # https://www.linkedin.com/in/nik9000/
person_dict_2y['romseygeek']['company'] = 'Elastic'  # https://www.linkedin.com/in/alan-woodward-0273253/
person_dict_2y['astefan']['company'] = 'Elastic' # https://www.linkedin.com/in/andreistefan/
person_dict_2y['iverase']['company'] = 'Elastic' # https://www.linkedin.com/in/ignacio-vera-79922916/
person_dict_2y['matriv']['company'] = 'Elastic' # https://www.linkedin.com/in/marios-trivyzas-5629b374/
person_dict_2y['talevy']['company'] = 'Elastic' # https://www.linkedin.com/in/talevy/
person_dict_2y['ywelsch']['company'] = 'Elastic' # https://www.linkedin.com/in/yannick-welsch-45780aa4/
person_dict_2y['imotov']['company'] = 'Elastic' # https://www.linkedin.com/in/imotov/
person_dict_2y['fcofdez']['company'] = 'Elastic' # https://www.linkedin.com/in/franciscofernandezcastano/
person_dict_2y['markharwood']['company'] = 'Elastic' # https://www.linkedin.com/in/elasticmark-harwood/
person_dict_2y['spinscale']['company'] = 'Elastic' # https://www.linkedin.com/in/alexanderreelsen/
person_dict_2y['hub-cap']['company'] = 'Elastic' # https://www.elastic.co/blog/author/michael-basnight
person_dict_2y['bizybot']['company'] = 'Elastic' # https://www.linkedin.com/in/gaikwadyogesh/
person_dict_2y['nknize']['company'] = 'Elastic' # https://www.linkedin.com/in/nknize/
person_dict_2y['valeriy42']['company'] = 'Elastic' # https://www.linkedin.com/in/khakhutskyy/
person_dict_2y['dliappis']['company'] = 'Elastic' # https://www.linkedin.com/in/dliappis/
person_dict_2y['rw-access']['company'] = 'Elastic' # https://www.linkedin.com/in/rossdwolf/
person_dict_2y['karmi']['company'] = 'Elastic' # https://www.linkedin.com/in/karelminarik/
person_dict_2y['andrershov']['company'] = 'Elastic' # https://www.linkedin.com/in/andrey-ershov-aba5302b/
person_dict_2y['jaymode']['company'] = 'Elastic' # use of jay@elastic.co email in some but not all time periods
person_dict_2y['henningandersen']['company'] = 'Elastic' # https://www.linkedin.com/in/henning-andersen-dk/

# Remove bots
try:
    del person_dict_2y['elasticmachine']
except:
    pass

# %%
org_people = 0
org_commits = 0
org_additions = 0
org_deletions = 0

other_people = 0
other_commits = 0
other_additions = 0
other_deletions = 0

for key,value in person_dict_2y.items():
    try:
        if value['commits'] >= 10:
            if value['company'] == 'Elastic':
                org_people += 1
                org_commits = org_commits + value['commits']
                org_additions = org_additions + value['additions']
                org_deletions = org_deletions + value['deletions']
            else:
                other_people += 1
                other_commits = other_commits + value['commits']
                other_additions = other_additions + value['additions']
                other_deletions = other_deletions + value['deletions']
                print(key,value)
            i+=1
    except:
        pass

print("\nElastic Employees with >= 10 commits:", "\n* People:", org_people, format(org_people/people, ".2%"), "of people")
print("* Commits:", org_commits, format(org_commits/commits, ".2%"), "of total commits")
print("* Additions:", org_additions, format(org_additions/additions, ".2%"), "of total additions")
print("* Deletions:", org_deletions, format(org_deletions/deletions, ".2%"), "of total deletions")

print("\nNon-Employees with >= 10 commits:", "\n* People:", other_people, format(other_people/people, ".2%"), "of people")
print("* Commits:", other_commits, format(other_commits/commits, ".2%"), "of total commits")
print("* Additions:", other_additions, format(other_additions/additions, ".2%"), "of total additions")
print("* Deletions:", other_deletions, format(other_deletions/deletions, ".2%"), "of total deletions")
      
print("\nTotals in dataset of people with >=10 commits:")
print('*', format((other_additions + org_additions)/additions, ".2%"), "of total additions")
print('*', format((other_deletions + org_deletions)/deletions, ".2%"), "of total deletions")
# Out:
# gaobinlong {'company': 'AWS', 'name': 'gaobinlong', 'commits': 55, 'additions': 3522, 'deletions': 618, 'email': ['gbl_long@163.com', 'gbinlong@amazon.com']}
# howardhuanghua {'company': 'Tencent', 'name': 'Howard', 'commits': 36, 'additions': 514, 'deletions': 171, 'email': ['danielhuang@tencent.com', 'howard-huang@qq.com']}
# Leaf-Lin {'company': None, 'name': None, 'commits': 11, 'additions': 64, 'deletions': 29, 'email': ['39002973+Leaf-Lin@users.noreply.github.com']}
# weizijun {'company': 'Alibaba', 'name': 'weizijun', 'commits': 11, 'additions': 438, 'deletions': 48, 'email': ['weizijun1989@gmail.com']}
# Hohol {'company': None, 'name': 'Nikita Glashenko', 'commits': 10, 'additions': 1320, 'deletions': 594, 'email': ['nikita.glashenko@gmail.com']}
#
# Elastic Employees with >= 10 commits:
# * People: 81 15.85% of people
# * Commits: 12311 93.24% of total commits
# * Additions: 2915551 97.35% of total additions
# * Deletions: 1628155 98.32% of total deletions
#
# ...

# %% [markdown]
# # 1 Year Before the Relicense (2020-02-03 - 2021-02-03)

# %%
from pprint import pprint
import collections
import pandas as pd
import pickle

# Pickle files generated by this script:
# https://github.com/chaoss/wg-data-science/blob/main/dataset/license-changes/fork-case-study/commits_people.py

people_pickle_1y = '../data-files/elasticsearch_people_2020-02-03T00:00:00.000+00:002021-02-03T00:00:00.000+00:00.pkl'

with open(people_pickle_1y, 'rb') as f:
    person_dict_1y = pickle.load(f)

# %%
people = len(person_dict_1y)
commits = 0
additions = 0
deletions = 0

for key,value in person_dict_1y.items():
    if value['company'] == None:
        for email in value['email']:
            if "elastic.co" in email:
                person_dict_1y[key]['company'] = 'Elastic'
    elif "elastic" in value['company'].lower():
        person_dict_1y[key]['company'] = 'Elastic'
        
    # Get descriptive statistics
    commits = commits + value['commits']
    additions = additions + value['additions']
    deletions = deletions + value['deletions']
    
print("People:", people)
print("Commits:", commits)
print("Additions", additions)
print("Deletions", deletions)
# Out:
# People: 319
# Commits: 7035
# Additions 1438019
# Deletions 644720

# %%
# Before cleanup
for key,value in person_dict_1y.items():
    #print(key,value['commits'])
    try:
        if value['commits'] >= 10:
            if value['company'] != 'Elastic':
                print(key,value)
    except:
        print(key,value)
# Out:
# henningandersen {'company': None, 'name': 'Henning Andersen', 'commits': 71, 'additions': 11381, 'deletions': 2937, 'email': ['33268011+henningandersen@users.noreply.github.com']}
# nik9000 {'company': None, 'name': 'Nik Everett', 'commits': 333, 'additions': 151164, 'deletions': 83519, 'email': ['nik9000@gmail.com']}
# gaobinlong {'company': 'AWS', 'name': 'gaobinlong', 'commits': 49, 'additions': 3450, 'deletions': 572, 'email': ['gbl_long@163.com', 'gbinlong@amazon.com']}
# romseygeek {'company': 'Romsey Software Ltd', 'name': 'Alan Woodward', 'commits': 159, 'additions': 32327, 'deletions': 35298, 'email': ['romseygeek@gmail.com', 'romseygeek@apache.org']}
# astefan {'company': None, 'name': 'Andrei Stefan', 'commits': 66, 'additions': 19573, 'deletions': 6560, 'email': ['astefan@users.noreply.github.com']}
# elasticmachine {'company': None, 'name': 'Elastic Machine', 'commits': 75, 'additions': 27537, 'deletions': 12122, 'email': ['elasticmachine@users.noreply.github.com']}
# ...

# %%
# Manual Fixes
person_dict_1y['nik9000']['company'] = 'Elastic' # https://www.linkedin.com/in/nik9000/
person_dict_1y['romseygeek']['company'] = 'Elastic'  # https://www.linkedin.com/in/alan-woodward-0273253/
person_dict_1y['astefan']['company'] = 'Elastic' # https://www.linkedin.com/in/andreistefan/
person_dict_1y['iverase']['company'] = 'Elastic' # https://www.linkedin.com/in/ignacio-vera-79922916/
person_dict_1y['matriv']['company'] = 'Elastic' # https://www.linkedin.com/in/marios-trivyzas-5629b374/
person_dict_1y['talevy']['company'] = 'Elastic' # https://www.linkedin.com/in/talevy/
person_dict_1y['ywelsch']['company'] = 'Elastic' # https://www.linkedin.com/in/yannick-welsch-45780aa4/
person_dict_1y['imotov']['company'] = 'Elastic' # https://www.linkedin.com/in/imotov/
person_dict_1y['fcofdez']['company'] = 'Elastic' # https://www.linkedin.com/in/franciscofernandezcastano/
person_dict_1y['markharwood']['company'] = 'Elastic' # https://www.linkedin.com/in/elasticmark-harwood/
person_dict_1y['spinscale']['company'] = 'Elastic' # https://www.linkedin.com/in/alexanderreelsen/
person_dict_1y['hub-cap']['company'] = 'Elastic' # https://www.elastic.co/blog/author/michael-basnight
person_dict_1y['bizybot']['company'] = 'Elastic' # https://www.linkedin.com/in/gaikwadyogesh/
person_dict_1y['nknize']['company'] = 'Elastic' # https://www.linkedin.com/in/nknize/
person_dict_1y['valeriy42']['company'] = 'Elastic' # https://www.linkedin.com/in/khakhutskyy/
person_dict_1y['dliappis']['company'] = 'Elastic' # https://www.linkedin.com/in/dliappis/
person_dict_1y['rw-access']['company'] = 'Elastic' # https://www.linkedin.com/in/rossdwolf/
person_dict_1y['karmi']['company'] = 'Elastic' # https://www.linkedin.com/in/karelminarik/
person_dict_1y['andrershov']['company'] = 'Elastic' # https://www.linkedin.com/in/andrey-ershov-aba5302b/
person_dict_1y['jaymode']['company'] = 'Elastic' # use of jay@elastic.co email in some but not all time periods
person_dict_1y['henningandersen']['company'] = 'Elastic' # https://www.linkedin.com/in/henning-andersen-dk/

# Remove bots
try:
    del person_dict_1y['elasticmachine']
except:
    pass

# %%
org_people = 0
org_commits = 0
org_additions = 0
org_deletions = 0

other_people = 0
other_commits = 0
other_additions = 0
other_deletions = 0

for key,value in person_dict_1y.items():
    try:
        if value['commits'] >= 10:
            if value['company'] == 'Elastic':
                org_people += 1
                org_commits = org_commits + value['commits']
                org_additions = org_additions + value['additions']
                org_deletions = org_deletions + value['deletions']
            else:
                other_people += 1
                other_commits = other_commits + value['commits']
                other_additions = other_additions + value['additions']
                other_deletions = other_deletions + value['deletions']
                print(key,value)
            i+=1
    except:
        pass

print("\nElastic Employees with >= 10 commits:", "\n* People:", org_people, format(org_people/people, ".2%"), "of people")
print("* Commits:", org_commits, format(org_commits/commits, ".2%"), "of total commits")
print("* Additions:", org_additions, format(org_additions/additions, ".2%"), "of total additions")
print("* Deletions:", org_deletions, format(org_deletions/deletions, ".2%"), "of total deletions")

print("\nNon-Employees with >= 10 commits:", "\n* People:", other_people, format(other_people/people, ".2%"), "of people")
print("* Commits:", other_commits, format(other_commits/commits, ".2%"), "of total commits")
print("* Additions:", other_additions, format(other_additions/additions, ".2%"), "of total additions")
print("* Deletions:", other_deletions, format(other_deletions/deletions, ".2%"), "of total deletions")
      
print("\nTotals in dataset of people with >=10 commits:")
print('*', format((other_additions + org_additions)/additions, ".2%"), "of total additions")
print('*', format((other_deletions + org_deletions)/deletions, ".2%"), "of total deletions")
# Out:
# gaobinlong {'company': 'AWS', 'name': 'gaobinlong', 'commits': 49, 'additions': 3450, 'deletions': 572, 'email': ['gbl_long@163.com', 'gbinlong@amazon.com']}
# howardhuanghua {'company': 'Tencent', 'name': 'Howard', 'commits': 34, 'additions': 341, 'deletions': 139, 'email': ['danielhuang@tencent.com', 'howard-huang@qq.com']}
# Leaf-Lin {'company': None, 'name': None, 'commits': 11, 'additions': 64, 'deletions': 29, 'email': ['39002973+Leaf-Lin@users.noreply.github.com']}
#
# Elastic Employees with >= 10 commits:
# * People: 67 21.00% of people
# * Commits: 6477 92.07% of total commits
# * Additions: 1377558 95.80% of total additions
# * Deletions: 623561 96.72% of total deletions
#
# Non-Employees with >= 10 commits:
# * People: 3 0.94% of people
# * Commits: 94 1.34% of total commits
# * Additions: 3855 0.27% of total additions
# * Deletions: 740 0.11% of total deletions
#
# Totals in dataset of people with >=10 commits:
# * 96.06% of total additions
# * 96.83% of total deletions

# %% [markdown]
# # 1 Year after the relicense (2021-02-03 - 2022-02-03)

# %%
from pprint import pprint
import collections
import pandas as pd
import pickle

# Pickle files generated by this script:
# https://github.com/chaoss/wg-data-science/blob/main/dataset/license-changes/fork-case-study/commits_people.py

people_pickle_1a = '../data-files/elasticsearch_people_2021-02-03T00:00:00.000+00:002022-02-03T00:00:00.000+00:00.pkl'

with open(people_pickle_1a, 'rb') as f:
    person_dict_1a = pickle.load(f)

# %%
people = len(person_dict_1a)
commits = 0
additions = 0
deletions = 0

for key,value in person_dict_1a.items():
    if value['company'] == None:
        for email in value['email']:
            if "elastic.co" in email:
                person_dict_1a[key]['company'] = 'Elastic'
    elif "elastic" in value['company'].lower():
        person_dict_1a[key]['company'] = 'Elastic'
        
    # Get descriptive statistics
    commits = commits + value['commits']
    additions = additions + value['additions']
    deletions = deletions + value['deletions']
    
print("People:", people)
print("Commits:", commits)
print("Additions", additions)
print("Deletions", deletions)
# Out:
# People: 269
# Commits: 6213
# Additions 1668900
# Deletions 1079149

# %%
# Before cleanup
for key,value in person_dict_1a.items():
    #print(key,value['commits'])
    try:
        if value['commits'] >= 10:
            if value['company'] != 'Elastic':
                print(key,value)
    except:
        print(key,value)
# Out:
# weizijun {'email': ['weizijun1989@gmail.com'], 'name': 'weizijun', 'company': 'Alibaba', 'additions': 5291, 'deletions': 1922, 'commits': 28}
# elasticmachine {'email': ['elasticmachine@users.noreply.github.com'], 'name': 'Elastic Machine', 'company': None, 'additions': 33122, 'deletions': 9552, 'commits': 129}
# talevy {'email': ['JubBoy333@gmail.com', 'jubboy333@gmail.com'], 'name': 'Tal Levy', 'company': None, 'additions': 1892, 'deletions': 1321, 'commits': 12}
# imotov {'email': ['igor@motovs.org'], 'name': 'Igor Motov', 'company': None, 'additions': 43713, 'deletions': 20607, 'commits': 45}
# gaobinlong {'email': ['gbl_long@163.com', 'gbinlong@amazon.com', 'gaobinlong@users.noreply.github.com'], 'name': 'gaobinlong', 'company': 'AWS', 'additions': 1992, 'deletions': 256, 'commits': 19}
# fcofdez {'email': ['francisco.fernandez.castano@gmail.com'], 'name': 'Francisco Fernández Castaño', 'company': None, 'additions': 21135, 'deletions': 2535, 'commits': 73}
# ...

# %%
# Manual Fixes
person_dict_1a['nik9000']['company'] = 'Elastic' # https://www.linkedin.com/in/nik9000/
person_dict_1a['romseygeek']['company'] = 'Elastic'  # https://www.linkedin.com/in/alan-woodward-0273253/
person_dict_1a['astefan']['company'] = 'Elastic' # https://www.linkedin.com/in/andreistefan/
person_dict_1a['iverase']['company'] = 'Elastic' # https://www.linkedin.com/in/ignacio-vera-79922916/
person_dict_1a['matriv']['company'] = 'Elastic' # https://www.linkedin.com/in/marios-trivyzas-5629b374/
person_dict_1a['talevy']['company'] = 'Elastic' # https://www.linkedin.com/in/talevy/
person_dict_1a['ywelsch']['company'] = 'Elastic' # https://www.linkedin.com/in/yannick-welsch-45780aa4/
person_dict_1a['imotov']['company'] = 'Elastic' # https://www.linkedin.com/in/imotov/
person_dict_1a['fcofdez']['company'] = 'Elastic' # https://www.linkedin.com/in/franciscofernandezcastano/
person_dict_1a['markharwood']['company'] = 'Elastic' # https://www.linkedin.com/in/elasticmark-harwood/
person_dict_1a['spinscale']['company'] = 'Elastic' # https://www.linkedin.com/in/alexanderreelsen/
person_dict_1a['hub-cap']['company'] = 'Elastic' # https://www.elastic.co/blog/author/michael-basnight
person_dict_1a['bizybot']['company'] = 'Elastic' # https://www.linkedin.com/in/gaikwadyogesh/
person_dict_1a['nknize']['company'] = 'Elastic' # https://www.linkedin.com/in/nknize/
person_dict_1a['valeriy42']['company'] = 'Elastic' # https://www.linkedin.com/in/khakhutskyy/
person_dict_1a['dliappis']['company'] = 'Elastic' # https://www.linkedin.com/in/dliappis/
person_dict_1a['rw-access']['company'] = 'Elastic' # https://www.linkedin.com/in/rossdwolf/
person_dict_1a['karmi']['company'] = 'Elastic' # https://www.linkedin.com/in/karelminarik/
person_dict_1a['andrershov']['company'] = 'Elastic' # https://www.linkedin.com/in/andrey-ershov-aba5302b/
person_dict_1a['jaymode']['company'] = 'Elastic' # use of jay@elastic.co email in some but not all time periods
person_dict_1a['henningandersen']['company'] = 'Elastic' # https://www.linkedin.com/in/henning-andersen-dk/
person_dict_1a['stefnestor']['company'] = 'Elastic' # https://www.linkedin.com/in/stefnestor/
person_dict_1a['grcevski']['company'] = 'Elastic' # https://www.linkedin.com/in/nikola-grcevski-16796717/

# Remove bots
try:
    del person_dict_1a['elasticmachine']
except:
    pass

# %%
org_people = 0
org_commits = 0
org_additions = 0
org_deletions = 0

other_people = 0
other_commits = 0
other_additions = 0
other_deletions = 0

for key,value in person_dict_1a.items():
    try:
        if value['commits'] >= 10:
            if value['company'] == 'Elastic':
                org_people += 1
                org_commits = org_commits + value['commits']
                org_additions = org_additions + value['additions']
                org_deletions = org_deletions + value['deletions']
            else:
                other_people += 1
                other_commits = other_commits + value['commits']
                other_additions = other_additions + value['additions']
                other_deletions = other_deletions + value['deletions']
                print(key,value)
            i+=1
    except:
        pass

print("\nElastic Employees with >= 10 commits:", "\n* People:", org_people, format(org_people/people, ".2%"), "of people")
print("* Commits:", org_commits, format(org_commits/commits, ".2%"), "of total commits")
print("* Additions:", org_additions, format(org_additions/additions, ".2%"), "of total additions")
print("* Deletions:", org_deletions, format(org_deletions/deletions, ".2%"), "of total deletions")

print("\nNon-Employees with >= 10 commits:", "\n* People:", other_people, format(other_people/people, ".2%"), "of people")
print("* Commits:", other_commits, format(other_commits/commits, ".2%"), "of total commits")
print("* Additions:", other_additions, format(other_additions/additions, ".2%"), "of total additions")
print("* Deletions:", other_deletions, format(other_deletions/deletions, ".2%"), "of total deletions")
      
print("\nTotals in dataset of people with >=10 commits:")
print('*', format((other_additions + org_additions)/additions, ".2%"), "of total additions")
print('*', format((other_deletions + org_deletions)/deletions, ".2%"), "of total deletions")
# Out:
# weizijun {'email': ['weizijun1989@gmail.com'], 'name': 'weizijun', 'company': 'Alibaba', 'additions': 5291, 'deletions': 1922, 'commits': 28}
# gaobinlong {'email': ['gbl_long@163.com', 'gbinlong@amazon.com', 'gaobinlong@users.noreply.github.com'], 'name': 'gaobinlong', 'company': 'AWS', 'additions': 1992, 'deletions': 256, 'commits': 19}
#
# Elastic Employees with >= 10 commits:
# * People: 65 24.16% of people
# * Commits: 5668 91.23% of total commits
# * Additions: 1597988 95.75% of total additions
# * Deletions: 1061154 98.33% of total deletions
#
# Non-Employees with >= 10 commits:
# * People: 2 0.74% of people
# * Commits: 47 0.76% of total commits
# * Additions: 7283 0.44% of total additions
# * Deletions: 2178 0.20% of total deletions
#
# Totals in dataset of people with >=10 commits:
# * 96.19% of total additions
# * 98.53% of total deletions

# %% [markdown]
# # 1 Year Before Adding AGPL (2023-08-29 - 2024-08-29)

# %%
from pprint import pprint
import collections
import pandas as pd
import pickle

# Pickle files generated by this script:
# https://github.com/chaoss/wg-data-science/blob/main/dataset/license-changes/fork-case-study/commits_people.py

people_pickle_1yrbagpl = '../data-files/elasticsearch_people_2023-08-29T00:00:00.000+00:002024-08-29T00:00:00.000+00:00.pkl'

with open(people_pickle_1yrbagpl, 'rb') as f:
    person_dict_1yrbagpl = pickle.load(f)

# %%
people = len(person_dict_1yrbagpl)
commits = 0
additions = 0
deletions = 0

for key,value in person_dict_1yrbagpl.items():
    if value['company'] == None:
        for email in value['email']:
            if "elastic.co" in email:
                person_dict_1yrbagpl[key]['company'] = 'Elastic'
    elif "elastic" in value['company'].lower():
        person_dict_1yrbagpl[key]['company'] = 'Elastic'
        
    # Get descriptive statistics
    commits = commits + value['commits']
    additions = additions + value['additions']
    deletions = deletions + value['deletions']
    
print("People:", people)
print("Commits:", commits)
print("Additions", additions)
print("Deletions", deletions)
# Out:
# People: 273
# Commits: 8052
# Additions 2771342
# Deletions 1155530

# %%
# Before cleanup
for key,value in person_dict_1yrbagpl.items():
    #print(key,value['commits'])
    try:
        if value['commits'] >= 10:
            if value['company'] != 'Elastic':
                print(key,value)
    except:
        print(key,value)
# Out:
# ChrisHegarty {'additions': 179101, 'email': ['62058229+ChrisHegarty@users.noreply.github.com', 'chegar999@gmail.com'], 'deletions': 59244, 'commits': 133, 'company': None, 'name': 'Chris Hegarty'}
# kingherc {'additions': 378, 'email': ['kingherc@gmail.com'], 'deletions': 214, 'commits': 26, 'company': None, 'name': 'Iraklis Psaroudakis'}
# n1v0lg {'additions': 7704, 'email': ['n1v0lg@users.noreply.github.com'], 'deletions': 3863, 'commits': 43, 'company': None, 'name': 'Nikolaj Volgushev'}
# stefnestor {'additions': 783, 'email': ['26751266+stefnestor@users.noreply.github.com'], 'deletions': 188, 'commits': 29, 'company': None, 'name': 'Stef Nestor'}
# JVerwolf {'additions': 2076, 'email': ['JVerwolf@users.noreply.github.com', 'osjdverwolf@gmail.com'], 'deletions': 546, 'commits': 15, 'company': None, 'name': 'John Verwolf'}
# ...

# %%
# Manual Fixes
person_dict_1yrbagpl['nik9000']['company'] = 'Elastic' # https://www.linkedin.com/in/nik9000/
person_dict_1yrbagpl['romseygeek']['company'] = 'Elastic'  # https://www.linkedin.com/in/alan-woodward-0273253/
person_dict_1yrbagpl['astefan']['company'] = 'Elastic' # https://www.linkedin.com/in/andreistefan/
person_dict_1yrbagpl['iverase']['company'] = 'Elastic' # https://www.linkedin.com/in/ignacio-vera-79922916/
person_dict_1yrbagpl['matriv']['company'] = 'Elastic' # https://www.linkedin.com/in/marios-trivyzas-5629b374/
person_dict_1yrbagpl['talevy']['company'] = 'Elastic' # https://www.linkedin.com/in/talevy/
person_dict_1yrbagpl['ywelsch']['company'] = 'Elastic' # https://www.linkedin.com/in/yannick-welsch-45780aa4/
person_dict_1yrbagpl['imotov']['company'] = 'Elastic' # https://www.linkedin.com/in/imotov/
person_dict_1yrbagpl['fcofdez']['company'] = 'Elastic' # https://www.linkedin.com/in/franciscofernandezcastano/
person_dict_1yrbagpl['markharwood']['company'] = 'Elastic' # https://www.linkedin.com/in/elasticmark-harwood/
person_dict_1yrbagpl['spinscale']['company'] = 'Elastic' # https://www.linkedin.com/in/alexanderreelsen/
person_dict_1yrbagpl['hub-cap']['company'] = 'Elastic' # https://www.elastic.co/blog/author/michael-basnight
person_dict_1yrbagpl['bizybot']['company'] = 'Elastic' # https://www.linkedin.com/in/gaikwadyogesh/
person_dict_1yrbagpl['nknize']['company'] = 'Elastic' # https://www.linkedin.com/in/nknize/
person_dict_1yrbagpl['valeriy42']['company'] = 'Elastic' # https://www.linkedin.com/in/khakhutskyy/
person_dict_1yrbagpl['dliappis']['company'] = 'Elastic' # https://www.linkedin.com/in/dliappis/
person_dict_1yrbagpl['rw-access']['company'] = 'Elastic' # https://www.linkedin.com/in/rossdwolf/
person_dict_1yrbagpl['karmi']['company'] = 'Elastic' # https://www.linkedin.com/in/karelminarik/
person_dict_1yrbagpl['andrershov']['company'] = 'Elastic' # https://www.linkedin.com/in/andrey-ershov-aba5302b/
person_dict_1yrbagpl['jaymode']['company'] = 'Elastic' # use of jay@elastic.co email in some but not all time periods
person_dict_1yrbagpl['henningandersen']['company'] = 'Elastic' # https://www.linkedin.com/in/henning-andersen-dk/
person_dict_1yrbagpl['ChrisHegarty']['company'] = 'Elastic' # https://www.linkedin.com/in/chegar999/
person_dict_1yrbagpl['kingherc']['company'] = 'Elastic' # https://www.linkedin.com/in/kingherc/
person_dict_1yrbagpl['n1v0lg']['company'] = 'Elastic' # https://www.linkedin.com/in/nikolaj-volgushev/
person_dict_1yrbagpl['stefnestor']['company'] = 'Elastic' # https://www.linkedin.com/in/stefnestor/
person_dict_1yrbagpl['JVerwolf']['company'] = 'Elastic' # https://www.linkedin.com/in/john-verwolf/
person_dict_1yrbagpl['mosche']['company'] = 'Elastic' # https://www.linkedin.com/in/moritzmack/
person_dict_1yrbagpl['luigidellaquila']['company'] = 'Elastic' # https://www.linkedin.com/in/luigidellaquila/
person_dict_1yrbagpl['jan-elastic']['company'] = 'Elastic' # username
person_dict_1yrbagpl['nielsbauman']['company'] = 'Elastic' # https://www.linkedin.com/in/niels-bauman-776b4a168/
person_dict_1yrbagpl['leemthompo']['company'] = 'Elastic' # https://www.linkedin.com/in/liam-thompson-62312624/
person_dict_1yrbagpl['fang-xing-esql']['company'] = 'Elastic' # https://www.linkedin.com/in/fang-xing-22929127/
person_dict_1yrbagpl['cbuescher']['company'] = 'Elastic' # https://www.linkedin.com/in/christophbuescher/
person_dict_1yrbagpl['jfreden']['company'] = 'Elastic' # https://www.linkedin.com/in/johannes-fred%C3%A9n-jansson-162a5727/

# Remove bots
try:
    del person_dict_1yrbagpl['elasticmachine']
except:
    pass

# %%
org_people = 0
org_commits = 0
org_additions = 0
org_deletions = 0

other_people = 0
other_commits = 0
other_additions = 0
other_deletions = 0

for key,value in person_dict_1yrbagpl.items():
    try:
        if value['commits'] >= 10:
            if value['company'] == 'Elastic':
                org_people += 1
                org_commits = org_commits + value['commits']
                org_additions = org_additions + value['additions']
                org_deletions = org_deletions + value['deletions']
            else:
                other_people += 1
                other_commits = other_commits + value['commits']
                other_additions = other_additions + value['additions']
                other_deletions = other_deletions + value['deletions']
                print(key,value)
            i+=1
    except:
        pass

print("\nElastic Employees with >= 10 commits:", "\n* People:", org_people, format(org_people/people, ".2%"), "of people")
print("* Commits:", org_commits, format(org_commits/commits, ".2%"), "of total commits")
print("* Additions:", org_additions, format(org_additions/additions, ".2%"), "of total additions")
print("* Deletions:", org_deletions, format(org_deletions/deletions, ".2%"), "of total deletions")

print("\nNon-Employees with >= 10 commits:", "\n* People:", other_people, format(other_people/people, ".2%"), "of people")
print("* Commits:", other_commits, format(other_commits/commits, ".2%"), "of total commits")
print("* Additions:", other_additions, format(other_additions/additions, ".2%"), "of total additions")
print("* Deletions:", other_deletions, format(other_deletions/deletions, ".2%"), "of total deletions")
      
print("\nTotals in dataset of people with >=10 commits:")
print('*', format((other_additions + org_additions)/additions, ".2%"), "of total additions")
print('*', format((other_deletions + org_deletions)/deletions, ".2%"), "of total deletions")
# Out:
# sabi0 {'additions': 326, 'email': ['2sabio@gmail.com'], 'deletions': 326, 'commits': 11, 'company': None, 'name': 'Dmitry Cherniachenko'}
#
# Elastic Employees with >= 10 commits:
# * People: 99 36.26% of people
# * Commits: 7616 94.59% of total commits
# * Additions: 2621830 94.61% of total additions
# * Deletions: 1123628 97.24% of total deletions
#
# Non-Employees with >= 10 commits:
# * People: 1 0.37% of people
# * Commits: 11 0.14% of total commits
# * Additions: 326 0.01% of total additions
# * Deletions: 326 0.03% of total deletions
#
# Totals in dataset of people with >=10 commits:
# * 94.62% of total additions
# * 97.27% of total deletions

# %% [markdown]
# # 6 Months after AGPL (2024-08-29 - 2025-02-29)

# %%
from pprint import pprint
import collections
import pandas as pd
import pickle

# Pickle files generated by this script:
# https://github.com/chaoss/wg-data-science/blob/main/dataset/license-changes/fork-case-study/commits_people.py

people_pickle_6moagpl = '../data-files/elasticsearch_people_2024-08-29T00:00:00.000+00:002025-02-29T00:00:00.000+00:00.pkl'

with open(people_pickle_6moagpl, 'rb') as f:
    person_dict_6moagpl = pickle.load(f)

# %%
people = len(person_dict_6moagpl)
commits = 0
additions = 0
deletions = 0

for key,value in person_dict_6moagpl.items():
    if value['company'] == None:
        for email in value['email']:
            if "elastic.co" in email:
                person_dict_6moagpl[key]['company'] = 'Elastic'
    elif "elastic" in value['company'].lower():
        person_dict_6moagpl[key]['company'] = 'Elastic'
        
    # Get descriptive statistics
    commits = commits + value['commits']
    additions = additions + value['additions']
    deletions = deletions + value['deletions']
    
print("People:", people)
print("Commits:", commits)
print("Additions", additions)
print("Deletions", deletions)
# Out:
# People: 236
# Commits: 5582
# Additions 3405887
# Deletions 3088484

# %%
# Before cleanup
for key,value in person_dict_6moagpl.items():
    #print(key,value['commits'])
    try:
        if value['commits'] >= 10:
            if value['company'] != 'Elastic':
                print(key,value)
    except:
        print(key,value)
# Out:
# nik9000 {'company': None, 'additions': 49378, 'name': 'Nik Everett', 'deletions': 24123, 'commits': 99, 'email': ['nik9000@gmail.com', 'nik9000@users.noreply.github.com']}
# valeriy42 {'company': None, 'additions': 666, 'name': 'Valeriy Khakhutskyy', 'deletions': 106, 'commits': 12, 'email': ['1292899+valeriy42@users.noreply.github.com']}
# elasticmachine {'company': None, 'additions': 52020, 'name': 'Elastic Machine', 'deletions': 15363, 'commits': 104, 'email': ['elasticmachine@users.noreply.github.com']}
# astefan {'company': None, 'additions': 2117, 'name': 'Andrei Stefan', 'deletions': 894, 'commits': 17, 'email': ['astefan@users.noreply.github.com']}
# luigidellaquila {'company': None, 'additions': 7468, 'name': "Luigi Dell'Aquila", 'deletions': 2029, 'commits': 48, 'email': ['luigi.dellaquila@gmail.com']}
# drempapis {'company': 'home', 'additions': 2541, 'name': 'Dimitris Rempapis', 'deletions': 2112, 'commits': 24, 'email': ['dimitris.rempapis@elastic.co']}
# ...

# %%
# Manual Fixes
person_dict_6moagpl['nik9000']['company'] = 'Elastic' # https://www.linkedin.com/in/nik9000/
person_dict_6moagpl['astefan']['company'] = 'Elastic' # https://www.linkedin.com/in/andreistefan/
person_dict_6moagpl['fcofdez']['company'] = 'Elastic' # https://www.linkedin.com/in/franciscofernandezcastano/
person_dict_6moagpl['valeriy42']['company'] = 'Elastic' # https://www.linkedin.com/in/khakhutskyy/
person_dict_6moagpl['ChrisHegarty']['company'] = 'Elastic' # https://www.linkedin.com/in/chegar999/
person_dict_6moagpl['kingherc']['company'] = 'Elastic' # https://www.linkedin.com/in/kingherc/
person_dict_6moagpl['n1v0lg']['company'] = 'Elastic' # https://www.linkedin.com/in/nikolaj-volgushev/
person_dict_6moagpl['stefnestor']['company'] = 'Elastic' # https://www.linkedin.com/in/stefnestor/
person_dict_6moagpl['mosche']['company'] = 'Elastic' # https://www.linkedin.com/in/moritzmack/
person_dict_6moagpl['luigidellaquila']['company'] = 'Elastic' # https://www.linkedin.com/in/luigidellaquila/
person_dict_6moagpl['jan-elastic']['company'] = 'Elastic' # username
person_dict_6moagpl['nielsbauman']['company'] = 'Elastic' # https://www.linkedin.com/in/niels-bauman-776b4a168/
person_dict_6moagpl['leemthompo']['company'] = 'Elastic' # https://www.linkedin.com/in/liam-thompson-62312624/
person_dict_6moagpl['cbuescher']['company'] = 'Elastic' # https://www.linkedin.com/in/christophbuescher/

person_dict_6moagpl['drempapis']['company'] = 'Elastic' # Elastic email
person_dict_6moagpl['smalyshev']['company'] = 'Elastic' # https://www.linkedin.com/in/smalyshev/
person_dict_6moagpl['shainaraskas']['company'] = 'Elastic' # https://www.linkedin.com/in/shaina-raskas-42853493/
person_dict_6moagpl['kosabogi']['company'] = 'Elastic' # https://www.linkedin.com/in/bogl%C3%A1rka-k%C3%B3sa-03670b151/

# Remove bots
try:
    del person_dict_6moagpl['elasticmachine']
    del person_dict_6moagpl['elastic-renovate-prod[bot]']
except:
    pass

# %%
org_people = 0
org_commits = 0
org_additions = 0
org_deletions = 0

other_people = 0
other_commits = 0
other_additions = 0
other_deletions = 0

for key,value in person_dict_6moagpl.items():
    try:
        if value['commits'] >= 10:
            if value['company'] == 'Elastic':
                org_people += 1
                org_commits = org_commits + value['commits']
                org_additions = org_additions + value['additions']
                org_deletions = org_deletions + value['deletions']
            else:
                other_people += 1
                other_commits = other_commits + value['commits']
                other_additions = other_additions + value['additions']
                other_deletions = other_deletions + value['deletions']
                print(key,value)
            i+=1
    except:
        pass

print("\nElastic Employees with >= 10 commits:", "\n* People:", org_people, format(org_people/people, ".2%"), "of people")
print("* Commits:", org_commits, format(org_commits/commits, ".2%"), "of total commits")
print("* Additions:", org_additions, format(org_additions/additions, ".2%"), "of total additions")
print("* Deletions:", org_deletions, format(org_deletions/deletions, ".2%"), "of total deletions")

print("\nNon-Employees with >= 10 commits:", "\n* People:", other_people, format(other_people/people, ".2%"), "of people")
print("* Commits:", other_commits, format(other_commits/commits, ".2%"), "of total commits")
print("* Additions:", other_additions, format(other_additions/additions, ".2%"), "of total additions")
print("* Deletions:", other_deletions, format(other_deletions/deletions, ".2%"), "of total deletions")
      
print("\nTotals in dataset of people with >=10 commits:")
print('*', format((other_additions + org_additions)/additions, ".2%"), "of total additions")
print('*', format((other_deletions + org_deletions)/deletions, ".2%"), "of total deletions")
# Out:
# Elastic Employees with >= 10 commits:
# * People: 92 38.98% of people
# * Commits: 5149 92.24% of total commits
# * Additions: 2997938 88.02% of total additions
# * Deletions: 2299643 74.46% of total deletions
#
# Non-Employees with >= 10 commits:
# * People: 0 0.00% of people
# * Commits: 0 0.00% of total commits
# * Additions: 0 0.00% of total additions
# * Deletions: 0 0.00% of total deletions
#
# Totals in dataset of people with >=10 commits:
# * 88.02% of total additions
# * 74.46% of total deletions
